# %%
import yfinance as yf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# Veriyi indirme ve inceleme
ticker_symbol = 'OSTIM.IS'
start_date = '2022-05-10'
end_date = '2024-04-10'
df = yf.download(ticker_symbol, period="10y", interval="1wk")
df['Date'] = pd.to_datetime(df.index)

# Veri hazırlama
df["Date"] = pd.to_datetime(df["Date"])
OSTIM_df = df[["Date", "Close"]]
OSTIM_df.index = OSTIM_df["Date"]
OSTIM_df.drop("Date", axis=1, inplace=True)
result_df = OSTIM_df.copy()
plt.figure(figsize=(12,6))
plt.plot(OSTIM_df['Close'], color='blue')
plt.ylabel('Fiyat')
plt.title('OSTIM Grafiği')
plt.xlabel('Zaman')
plt.show()

# Veri önişleme
OSTIM_df = OSTIM_df.values.astype('float32')
def split_data(dataframe, test_size):
    pos = int(round(len(dataframe) * (1 - test_size)))
    train = dataframe[:pos]
    test = dataframe[pos:]
    return train, test, pos

train, test, pos = split_data(OSTIM_df, 0.20)
scaler_train = MinMaxScaler(feature_range=(0, 1))
train = scaler_train.fit_transform(train)
scaler_test = MinMaxScaler(feature_range=(0, 1))
test = scaler_test.fit_transform(test)

def create_features(data, lookback):
    X, Y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i-lookback:i, 0])
        Y.append(data[i, 0])
    return np.array(X), np.array(Y)

lookback = 4
X_train, Y_train = create_features(train, lookback)
X_test, Y_test = create_features(test, lookback)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
Y_train = Y_train.reshape(-1, 1)
Y_test = Y_test.reshape(-1, 1)

# Model oluşturma
model = Sequential([
    SimpleRNN(units=20, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], lookback)),
    Dropout(0.1),
    SimpleRNN(units=10, activation='relu'),
    Dropout(0.1),
    Dense(1)
])


model.summary()

# Optimizasyon
optimizer = Adam(learning_rate=0.0001)
model.compile(loss='mean_squared_error', optimizer=optimizer)

# Callback'ler
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode="min"),
    ModelCheckpoint(filepath='OSTIM.h5', monitor='val_loss', mode='min',
                    save_best_only=True, save_weights_only=False, verbose=1)
]

# Model eğitimi
history = model.fit(
    x=X_train,
    y=Y_train,
    epochs=1000,
    batch_size=32,
    validation_data=(X_test, Y_test),
    callbacks=callbacks,
    shuffle=False
)

# Eğitim ve doğrulama kaybını görselleştirme
plt.figure(figsize=(20,5))
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.legend(loc='upper right')
plt.xlabel('Epok', fontsize=16)
plt.ylabel('Kayıp', fontsize=16)
plt.ylim([0,max(plt.ylim())])
plt.title('Eğitim ve Doğrulama Kaybı', fontsize=16)
plt.show()

# Model değerlendirme
loss = model.evaluate(X_test, Y_test, batch_size=32)
print("\nTest kaybı: %.1f%%" % (100.0 * loss))
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
train_predict = scaler_train.inverse_transform(train_predict)
test_predict = scaler_test.inverse_transform(test_predict)
Y_train = scaler_train.inverse_transform(Y_train)
Y_test = scaler_test.inverse_transform(Y_test)


# Tahminleri görselleştirme
train_prediction_df = result_df[lookback:pos]
train_prediction_df["Tahmin Edilen"] = train_predict
test_prediction_df = result_df[pos+lookback:]
test_prediction_df["Tahmin Edilen"] = test_predict

plt.figure(figsize=(14,5))
plt.plot(result_df, label='Gerçek Değerler')
plt.plot(train_prediction_df["Tahmin Edilen"], color='blue', label='Eğitim Tahmini')
plt.plot(test_prediction_df["Tahmin Edilen"], color="red", label='Test Tahmini')
plt.xlabel('Zaman')
plt.ylabel('Fiyat')
plt.title('OSTIMAN GRAFİĞİ')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\musab\AppData\Local\Temp\ipykernel_17940\4282164576.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OSTIM_df.drop("Date", axis=1, inplace=True)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 20)             500
#
#  dropout (Dropout)           (None, 1, 20)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 10)                310
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 821
# Trainable params: 821
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2872
# Epoch 1: val_loss improved from inf to 0.32543, saving model to OSTIM.h5
# 13/13 [==============================] - 4s 63ms/step - loss: 0.3079 - val_loss: 0.3254
# Epoch 2/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.3025
# Epoch 2: val_loss improved from 0.32543 to 0.31268, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.3025 - val_loss: 0.3127
# Epoch 3/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.1937
# Epoch 3: val_loss improved from 0.31268 to 0.30073, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.2875 - val_loss: 0.3007
# Epoch 4/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.2640
# Epoch 4: val_loss improved from 0.30073 to 0.28935, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.2640 - val_loss: 0.2893
# Epoch 5/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.2600
# Epoch 5: val_loss improved from 0.28935 to 0.27860, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.2600 - val_loss: 0.2786
# Epoch 6/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.2533
# Epoch 6: val_loss improved from 0.27860 to 0.26847, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.2533 - val_loss: 0.2685
# Epoch 7/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2326
# Epoch 7: val_loss improved from 0.26847 to 0.25880, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 38ms/step - loss: 0.2500 - val_loss: 0.2588
# Epoch 8/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2193
# Epoch 8: val_loss improved from 0.25880 to 0.24960, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 32ms/step - loss: 0.2412 - val_loss: 0.2496
# Epoch 9/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2129
# Epoch 9: val_loss improved from 0.24960 to 0.24074, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.2341 - val_loss: 0.2407
# Epoch 10/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.2106
# Epoch 10: val_loss improved from 0.24074 to 0.23210, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.2248 - val_loss: 0.2321
# Epoch 11/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1978
# Epoch 11: val_loss improved from 0.23210 to 0.22393, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.2165 - val_loss: 0.2239
# Epoch 12/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1822
# Epoch 12: val_loss improved from 0.22393 to 0.21614, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.2002 - val_loss: 0.2161
# Epoch 13/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.1978
# Epoch 13: val_loss improved from 0.21614 to 0.20870, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.1978 - val_loss: 0.2087
# Epoch 14/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.1301
# Epoch 14: val_loss improved from 0.20870 to 0.20143, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.1931 - val_loss: 0.2014
# Epoch 15/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1719
# Epoch 15: val_loss improved from 0.20143 to 0.19452, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.1854 - val_loss: 0.1945
# Epoch 16/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.1122
# Epoch 16: val_loss improved from 0.19452 to 0.18790, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.1784 - val_loss: 0.1879
# Epoch 17/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1604
# Epoch 17: val_loss improved from 0.18790 to 0.18137, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.1767 - val_loss: 0.1814
# Epoch 18/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.1699
# Epoch 18: val_loss improved from 0.18137 to 0.17480, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.1699 - val_loss: 0.1748
# Epoch 19/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.1604
# Epoch 19: val_loss improved from 0.17480 to 0.16845, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.1604 - val_loss: 0.1684
# Epoch 20/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.1531
# Epoch 20: val_loss improved from 0.16845 to 0.16247, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.1531 - val_loss: 0.1625
# Epoch 21/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1364
# Epoch 21: val_loss improved from 0.16247 to 0.15663, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.1505 - val_loss: 0.1566
# Epoch 22/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.1445
# Epoch 22: val_loss improved from 0.15663 to 0.15085, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 32ms/step - loss: 0.1445 - val_loss: 0.1508
# Epoch 23/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.1494
# Epoch 23: val_loss improved from 0.15085 to 0.14538, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.1494 - val_loss: 0.1454
# Epoch 24/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.1355
# Epoch 24: val_loss improved from 0.14538 to 0.13995, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.1355 - val_loss: 0.1400
# Epoch 25/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0834
# Epoch 25: val_loss improved from 0.13995 to 0.13465, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.1300 - val_loss: 0.1346
# Epoch 26/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0826
# Epoch 26: val_loss improved from 0.13465 to 0.12940, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.1294 - val_loss: 0.1294
# Epoch 27/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.1269
# Epoch 27: val_loss improved from 0.12940 to 0.12430, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.1269 - val_loss: 0.1243
# Epoch 28/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0779
# Epoch 28: val_loss improved from 0.12430 to 0.11920, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.1267 - val_loss: 0.1192
# Epoch 29/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1126
# Epoch 29: val_loss improved from 0.11920 to 0.11426, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.1246 - val_loss: 0.1143
# Epoch 30/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1050
# Epoch 30: val_loss improved from 0.11426 to 0.10955, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.1153 - val_loss: 0.1096
# Epoch 31/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.1014
# Epoch 31: val_loss improved from 0.10955 to 0.10504, saving model to OSTIM.h5
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1014 - val_loss: 0.1050
# Epoch 32/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.1137
# Epoch 32: val_loss improved from 0.10504 to 0.10076, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.1137 - val_loss: 0.1008
# Epoch 33/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0920
# Epoch 33: val_loss improved from 0.10076 to 0.09672, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0998 - val_loss: 0.0967
# Epoch 34/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0586
# Epoch 34: val_loss improved from 0.09672 to 0.09290, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0919 - val_loss: 0.0929
# Epoch 35/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0496
# Epoch 35: val_loss improved from 0.09290 to 0.08914, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0834 - val_loss: 0.0891
# Epoch 36/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0875
# Epoch 36: val_loss improved from 0.08914 to 0.08559, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0961 - val_loss: 0.0856
# Epoch 37/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0608
# Epoch 37: val_loss improved from 0.08559 to 0.08227, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0949 - val_loss: 0.0823
# Epoch 38/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0822
# Epoch 38: val_loss improved from 0.08227 to 0.07909, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0908 - val_loss: 0.0791
# Epoch 39/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0452
# Epoch 39: val_loss improved from 0.07909 to 0.07604, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0784 - val_loss: 0.0760
# Epoch 40/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0533
# Epoch 40: val_loss improved from 0.07604 to 0.07317, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0793 - val_loss: 0.0732
# Epoch 41/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0856
# Epoch 41: val_loss improved from 0.07317 to 0.07039, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0856 - val_loss: 0.0704
# Epoch 42/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0682
# Epoch 42: val_loss improved from 0.07039 to 0.06763, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0745 - val_loss: 0.0676
# Epoch 43/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0436
# Epoch 43: val_loss improved from 0.06763 to 0.06490, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0738 - val_loss: 0.0649
# Epoch 44/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0633
# Epoch 44: val_loss improved from 0.06490 to 0.06239, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0693 - val_loss: 0.0624
# Epoch 45/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0665
# Epoch 45: val_loss improved from 0.06239 to 0.06003, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0740 - val_loss: 0.0600
# Epoch 46/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0691
# Epoch 46: val_loss improved from 0.06003 to 0.05775, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0691 - val_loss: 0.0577
# Epoch 47/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0712
# Epoch 47: val_loss improved from 0.05775 to 0.05558, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0712 - val_loss: 0.0556
# Epoch 48/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0483
# Epoch 48: val_loss improved from 0.05558 to 0.05357, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0696 - val_loss: 0.0536
# Epoch 49/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0436
# Epoch 49: val_loss improved from 0.05357 to 0.05169, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0639 - val_loss: 0.0517
# Epoch 50/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0590
# Epoch 50: val_loss improved from 0.05169 to 0.04983, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0590 - val_loss: 0.0498
# Epoch 51/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0560
# Epoch 51: val_loss improved from 0.04983 to 0.04811, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0560 - val_loss: 0.0481
# Epoch 52/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0390
# Epoch 52: val_loss improved from 0.04811 to 0.04648, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0547 - val_loss: 0.0465
# Epoch 53/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0637
# Epoch 53: val_loss improved from 0.04648 to 0.04487, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0654 - val_loss: 0.0449
# Epoch 54/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0587
# Epoch 54: val_loss improved from 0.04487 to 0.04327, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0587 - val_loss: 0.0433
# Epoch 55/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0369
# Epoch 55: val_loss improved from 0.04327 to 0.04177, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0548 - val_loss: 0.0418
# Epoch 56/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0543
# Epoch 56: val_loss improved from 0.04177 to 0.04038, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0543 - val_loss: 0.0404
# Epoch 57/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0602
# Epoch 57: val_loss improved from 0.04038 to 0.03902, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0602 - val_loss: 0.0390
# Epoch 58/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0437
# Epoch 58: val_loss improved from 0.03902 to 0.03770, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0460 - val_loss: 0.0377
# Epoch 59/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0333
# Epoch 59: val_loss improved from 0.03770 to 0.03650, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0513 - val_loss: 0.0365
# Epoch 60/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0498
# Epoch 60: val_loss improved from 0.03650 to 0.03532, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0549 - val_loss: 0.0353
# Epoch 61/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0407
# Epoch 61: val_loss improved from 0.03532 to 0.03419, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0461 - val_loss: 0.0342
# Epoch 62/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0370
# Epoch 62: val_loss improved from 0.03419 to 0.03307, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0528 - val_loss: 0.0331
# Epoch 63/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0353
# Epoch 63: val_loss improved from 0.03307 to 0.03201, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0401 - val_loss: 0.0320
# Epoch 64/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0393
# Epoch 64: val_loss improved from 0.03201 to 0.03105, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0438 - val_loss: 0.0310
# Epoch 65/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0483
# Epoch 65: val_loss improved from 0.03105 to 0.03014, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0486 - val_loss: 0.0301
# Epoch 66/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0356
# Epoch 66: val_loss improved from 0.03014 to 0.02919, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0500 - val_loss: 0.0292
# Epoch 67/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0373
# Epoch 67: val_loss improved from 0.02919 to 0.02824, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0491 - val_loss: 0.0282
# Epoch 68/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0406
# Epoch 68: val_loss improved from 0.02824 to 0.02736, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0406 - val_loss: 0.0274
# Epoch 69/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0395
# Epoch 69: val_loss improved from 0.02736 to 0.02655, saving model to OSTIM.h5
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0395 - val_loss: 0.0265
# Epoch 70/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0416
# Epoch 70: val_loss improved from 0.02655 to 0.02577, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0449 - val_loss: 0.0258
# Epoch 71/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0486
# Epoch 71: val_loss improved from 0.02577 to 0.02504, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0486 - val_loss: 0.0250
# Epoch 72/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0495
# Epoch 72: val_loss improved from 0.02504 to 0.02433, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0494 - val_loss: 0.0243
# Epoch 73/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0391
# Epoch 73: val_loss improved from 0.02433 to 0.02367, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0391 - val_loss: 0.0237
# Epoch 74/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0420
# Epoch 74: val_loss improved from 0.02367 to 0.02307, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0420 - val_loss: 0.0231
# Epoch 75/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0264
# Epoch 75: val_loss improved from 0.02307 to 0.02246, saving model to OSTIM.h5
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0365 - val_loss: 0.0225
# Epoch 76/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0272
# Epoch 76: val_loss improved from 0.02246 to 0.02186, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0359 - val_loss: 0.0219
# Epoch 77/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0360
# Epoch 77: val_loss improved from 0.02186 to 0.02130, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0360 - val_loss: 0.0213
# Epoch 78/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0361
# Epoch 78: val_loss improved from 0.02130 to 0.02069, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0385 - val_loss: 0.0207
# Epoch 79/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0307
# Epoch 79: val_loss improved from 0.02069 to 0.02006, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0319 - val_loss: 0.0201
# Epoch 80/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0264
# Epoch 80: val_loss improved from 0.02006 to 0.01950, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0320 - val_loss: 0.0195
# Epoch 81/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0307
# Epoch 81: val_loss improved from 0.01950 to 0.01899, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0307 - val_loss: 0.0190
# Epoch 82/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0242
# Epoch 82: val_loss improved from 0.01899 to 0.01852, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0244 - val_loss: 0.0185
# Epoch 83/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0296
# Epoch 83: val_loss improved from 0.01852 to 0.01805, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0315 - val_loss: 0.0180
# Epoch 84/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0286
# Epoch 84: val_loss improved from 0.01805 to 0.01756, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0304 - val_loss: 0.0176
# Epoch 85/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0408
# Epoch 85: val_loss improved from 0.01756 to 0.01710, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0408 - val_loss: 0.0171
# Epoch 86/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0300
# Epoch 86: val_loss improved from 0.01710 to 0.01666, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0335 - val_loss: 0.0167
# Epoch 87/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0331
# Epoch 87: val_loss improved from 0.01666 to 0.01623, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0335 - val_loss: 0.0162
# Epoch 88/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0315
# Epoch 88: val_loss improved from 0.01623 to 0.01582, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0327 - val_loss: 0.0158
# Epoch 89/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0408
# Epoch 89: val_loss improved from 0.01582 to 0.01537, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0408 - val_loss: 0.0154
# Epoch 90/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0316
# Epoch 90: val_loss improved from 0.01537 to 0.01493, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0317 - val_loss: 0.0149
# Epoch 91/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0317
# Epoch 91: val_loss improved from 0.01493 to 0.01449, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0317 - val_loss: 0.0145
# Epoch 92/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0268
# Epoch 92: val_loss improved from 0.01449 to 0.01408, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0268 - val_loss: 0.0141
# Epoch 93/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0323
# Epoch 93: val_loss improved from 0.01408 to 0.01369, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0323 - val_loss: 0.0137
# Epoch 94/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0292
# Epoch 94: val_loss improved from 0.01369 to 0.01333, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0325 - val_loss: 0.0133
# Epoch 95/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0305
# Epoch 95: val_loss improved from 0.01333 to 0.01301, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0305 - val_loss: 0.0130
# Epoch 96/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0247
# Epoch 96: val_loss improved from 0.01301 to 0.01275, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0351 - val_loss: 0.0127
# Epoch 97/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0270
# Epoch 97: val_loss improved from 0.01275 to 0.01249, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0304 - val_loss: 0.0125
# Epoch 98/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0384
# Epoch 98: val_loss improved from 0.01249 to 0.01224, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0375 - val_loss: 0.0122
# Epoch 99/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0250
# Epoch 99: val_loss improved from 0.01224 to 0.01197, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0269 - val_loss: 0.0120
# Epoch 100/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0285
# Epoch 100: val_loss improved from 0.01197 to 0.01174, saving model to OSTIM.h5
# 13/13 [==============================] - 1s 43ms/step - loss: 0.0301 - val_loss: 0.0117
# Epoch 101/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0274
# Epoch 101: val_loss improved from 0.01174 to 0.01155, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0303 - val_loss: 0.0116
# Epoch 102/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0378
# Epoch 102: val_loss improved from 0.01155 to 0.01140, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0378 - val_loss: 0.0114
# Epoch 103/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0349
# Epoch 103: val_loss improved from 0.01140 to 0.01120, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0352 - val_loss: 0.0112
# Epoch 104/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0168
# Epoch 104: val_loss improved from 0.01120 to 0.01100, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0279 - val_loss: 0.0110
# Epoch 105/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0269
# Epoch 105: val_loss improved from 0.01100 to 0.01084, saving model to OSTIM.h5
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0293 - val_loss: 0.0108
# Epoch 106/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0253
# Epoch 106: val_loss improved from 0.01084 to 0.01068, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0301 - val_loss: 0.0107
# Epoch 107/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0176
# Epoch 107: val_loss improved from 0.01068 to 0.01048, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0280 - val_loss: 0.0105
# Epoch 108/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0205
# Epoch 108: val_loss improved from 0.01048 to 0.01031, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0219 - val_loss: 0.0103
# Epoch 109/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 109: val_loss improved from 0.01031 to 0.01018, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0198 - val_loss: 0.0102
# Epoch 110/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0256
# Epoch 110: val_loss improved from 0.01018 to 0.01006, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0278 - val_loss: 0.0101
# Epoch 111/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0304
# Epoch 111: val_loss improved from 0.01006 to 0.01000, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0340 - val_loss: 0.0100
# Epoch 112/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0192
# Epoch 112: val_loss improved from 0.01000 to 0.00992, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0265 - val_loss: 0.0099
# Epoch 113/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0212
# Epoch 113: val_loss improved from 0.00992 to 0.00979, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0235 - val_loss: 0.0098
# Epoch 114/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0235
# Epoch 114: val_loss improved from 0.00979 to 0.00968, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0254 - val_loss: 0.0097
# Epoch 115/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0304
# Epoch 115: val_loss improved from 0.00968 to 0.00958, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0326 - val_loss: 0.0096
# Epoch 116/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0152
# Epoch 116: val_loss improved from 0.00958 to 0.00948, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0168 - val_loss: 0.0095
# Epoch 117/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0214
# Epoch 117: val_loss improved from 0.00948 to 0.00941, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0262 - val_loss: 0.0094
# Epoch 118/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0210
# Epoch 118: val_loss improved from 0.00941 to 0.00936, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0257 - val_loss: 0.0094
# Epoch 119/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0258
# Epoch 119: val_loss improved from 0.00936 to 0.00929, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0258 - val_loss: 0.0093
# Epoch 120/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0227
# Epoch 120: val_loss improved from 0.00929 to 0.00923, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0308 - val_loss: 0.0092
# Epoch 121/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0246
# Epoch 121: val_loss improved from 0.00923 to 0.00920, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0246 - val_loss: 0.0092
# Epoch 122/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0273
# Epoch 122: val_loss improved from 0.00920 to 0.00918, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0273 - val_loss: 0.0092
# Epoch 123/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0116
# Epoch 123: val_loss improved from 0.00918 to 0.00911, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0218 - val_loss: 0.0091
# Epoch 124/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0250
# Epoch 124: val_loss improved from 0.00911 to 0.00898, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0271 - val_loss: 0.0090
# Epoch 125/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0172
# Epoch 125: val_loss improved from 0.00898 to 0.00887, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0246 - val_loss: 0.0089
# Epoch 126/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0181
# Epoch 126: val_loss improved from 0.00887 to 0.00876, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0202 - val_loss: 0.0088
# Epoch 127/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0173
# Epoch 127: val_loss improved from 0.00876 to 0.00871, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0261 - val_loss: 0.0087
# Epoch 128/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0190
# Epoch 128: val_loss improved from 0.00871 to 0.00863, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0199 - val_loss: 0.0086
# Epoch 129/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0244
# Epoch 129: val_loss improved from 0.00863 to 0.00852, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0244 - val_loss: 0.0085
# Epoch 130/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0248
# Epoch 130: val_loss improved from 0.00852 to 0.00847, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0244 - val_loss: 0.0085
# Epoch 131/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0178
# Epoch 131: val_loss did not improve from 0.00847
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0178 - val_loss: 0.0085
# Epoch 132/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0185
# Epoch 132: val_loss improved from 0.00847 to 0.00846, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0254 - val_loss: 0.0085
# Epoch 133/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0224
# Epoch 133: val_loss improved from 0.00846 to 0.00841, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0262 - val_loss: 0.0084
# Epoch 134/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0184
# Epoch 134: val_loss improved from 0.00841 to 0.00838, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 39ms/step - loss: 0.0280 - val_loss: 0.0084
# Epoch 135/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0190
# Epoch 135: val_loss improved from 0.00838 to 0.00831, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0190 - val_loss: 0.0083
# Epoch 136/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0291
# Epoch 136: val_loss improved from 0.00831 to 0.00825, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0305 - val_loss: 0.0083
# Epoch 137/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0187
# Epoch 137: val_loss improved from 0.00825 to 0.00820, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0246 - val_loss: 0.0082
# Epoch 138/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0143
# Epoch 138: val_loss improved from 0.00820 to 0.00816, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0218 - val_loss: 0.0082
# Epoch 139/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0237
# Epoch 139: val_loss improved from 0.00816 to 0.00810, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0253 - val_loss: 0.0081
# Epoch 140/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0230
# Epoch 140: val_loss improved from 0.00810 to 0.00805, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 39ms/step - loss: 0.0230 - val_loss: 0.0080
# Epoch 141/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0205
# Epoch 141: val_loss improved from 0.00805 to 0.00803, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0268 - val_loss: 0.0080
# Epoch 142/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0203
# Epoch 142: val_loss improved from 0.00803 to 0.00797, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0232 - val_loss: 0.0080
# Epoch 143/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0216
# Epoch 143: val_loss improved from 0.00797 to 0.00794, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0240 - val_loss: 0.0079
# Epoch 144/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0245
# Epoch 144: val_loss improved from 0.00794 to 0.00792, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0245 - val_loss: 0.0079
# Epoch 145/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0284
# Epoch 145: val_loss improved from 0.00792 to 0.00786, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0288 - val_loss: 0.0079
# Epoch 146/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0210
# Epoch 146: val_loss improved from 0.00786 to 0.00780, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0236 - val_loss: 0.0078
# Epoch 147/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0183
# Epoch 147: val_loss improved from 0.00780 to 0.00778, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0264 - val_loss: 0.0078
# Epoch 148/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0199
# Epoch 148: val_loss improved from 0.00778 to 0.00773, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0208 - val_loss: 0.0077
# Epoch 149/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0195
# Epoch 149: val_loss improved from 0.00773 to 0.00767, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0217 - val_loss: 0.0077
# Epoch 150/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0234
# Epoch 150: val_loss improved from 0.00767 to 0.00763, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0255 - val_loss: 0.0076
# Epoch 151/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0172
# Epoch 151: val_loss improved from 0.00763 to 0.00756, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0177 - val_loss: 0.0076
# Epoch 152/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0200
# Epoch 152: val_loss improved from 0.00756 to 0.00753, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0219 - val_loss: 0.0075
# Epoch 153/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0286
# Epoch 153: val_loss improved from 0.00753 to 0.00748, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0286 - val_loss: 0.0075
# Epoch 154/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 154: val_loss improved from 0.00748 to 0.00745, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0207 - val_loss: 0.0074
# Epoch 155/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0212
# Epoch 155: val_loss improved from 0.00745 to 0.00742, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0219 - val_loss: 0.0074
# Epoch 156/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0200
# Epoch 156: val_loss improved from 0.00742 to 0.00737, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0234 - val_loss: 0.0074
# Epoch 157/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0122
# Epoch 157: val_loss improved from 0.00737 to 0.00731, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0221 - val_loss: 0.0073
# Epoch 158/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0136
# Epoch 158: val_loss did not improve from 0.00731
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0155 - val_loss: 0.0073
# Epoch 159/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0282
# Epoch 159: val_loss improved from 0.00731 to 0.00729, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0282 - val_loss: 0.0073
# Epoch 160/1000
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0150
# Epoch 160: val_loss improved from 0.00729 to 0.00729, saving model to OSTIM.h5
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0249 - val_loss: 0.0073
# Epoch 161/1000
# 13/13 [==============================] - ETA: 0s - loss: 0.0207
# Epoch 161: val_loss did not improve from 0.00729
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0207 - val_loss: 0.0073
# Epoch 162/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0156
# Epoch 162: val_loss did not improve from 0.00729
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0172 - val_loss: 0.0074
# Epoch 163/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0159
# Epoch 163: val_loss did not improve from 0.00729
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0184 - val_loss: 0.0074
# Epoch 164/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0179
# Epoch 164: val_loss did not improve from 0.00729
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0178 - val_loss: 0.0074
# Epoch 165/1000
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0260
# Epoch 165: val_loss did not improve from 0.00729
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0276 - val_loss: 0.0073
# Epoch 165: early stopping
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0073
#
# Test kaybı: 0.7%
# 13/13 [==============================] - 1s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# C:\Users\musab\AppData\Local\Temp\ipykernel_17940\4282164576.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_prediction_df["Tahmin Edilen"] = train_predict
# C:\Users\musab\AppData\Local\Temp\ipykernel_17940\4282164576.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_prediction_df["Tahmin Edilen"] = test_predict

# %%
#MAE hesaplama
train_mae = mean_absolute_error(Y_train, train_predict)
test_mae = mean_absolute_error(Y_test, test_predict)
print(f"Eğitim MAE: {train_mae}")
print(f"Test MAE: {test_mae}")

#MAPE hesaplama
train_mape = mean_absolute_percentage_error(Y_train, train_predict) * 100
test_mape = mean_absolute_percentage_error(Y_test, test_predict) * 100
print(f"Eğitim MAPE: {train_mape}%")
print(f"Test MAPE: {test_mape}%")

#RMSE hesaplama
train_rmse = np.sqrt(mean_squared_error(Y_train, train_predict))
test_rmse = np.sqrt(mean_squared_error(Y_test, test_predict))
print(f"Eğitim RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Eğitim MAE: 0.08979186415672302
# Test MAE: 0.6772276163101196
# Eğitim MAPE: 6.949520856142044%
# Test MAPE: 10.20667627453804%
# Eğitim RMSE: 0.14064602553844452
# Test RMSE: 1.056226372718811
