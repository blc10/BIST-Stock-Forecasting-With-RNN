# %%
import yfinance as yf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# Veriyi indirme ve inceleme
ticker_symbol = 'TUPRS.IS'
start_date = '2022-05-10'
end_date = '2024-04-10'
df = yf.download(ticker_symbol, period="10y", interval="1d")
df['Date'] = pd.to_datetime(df.index)


# Veri hazırlama
df["Date"] = pd.to_datetime(df["Date"])
tuprsao_df = df[["Date", "Close"]]
tuprsao_df.index = tuprsao_df["Date"]
tuprsao_df.drop("Date", axis=1, inplace=True)
result_df = tuprsao_df.copy()
plt.figure(figsize=(12,6))
plt.plot(tuprsao_df['Close'], color='blue')
plt.ylabel('Fiyat')
plt.title('tuprsao Grafiği')
plt.xlabel('Zaman')
plt.show()

# Veri önişleme
tuprsao_df = tuprsao_df.values.astype('float32')
def split_data(dataframe, test_size):
    pos = int(round(len(dataframe) * (1 - test_size)))
    train = dataframe[:pos]
    test = dataframe[pos:]
    return train, test, pos

train, test, pos = split_data(tuprsao_df, 0.20)
scaler_train = MinMaxScaler(feature_range=(0, 1))
train = scaler_train.fit_transform(train)
scaler_test = MinMaxScaler(feature_range=(0, 1))
test = scaler_test.fit_transform(test)

def create_features(data, lookback):
    X, Y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i-lookback:i, 0])
        Y.append(data[i, 0])
    return np.array(X), np.array(Y)

lookback = 20
X_train, Y_train = create_features(train, lookback)
X_test, Y_test = create_features(test, lookback)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
Y_train = Y_train.reshape(-1, 1)
Y_test = Y_test.reshape(-1, 1)

# Model oluşturma
model = Sequential([
    SimpleRNN(units=20, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], lookback)),
    Dropout(0.1),
    SimpleRNN(units=10, activation='relu'),
    Dropout(0.1),
    Dense(1)
])


model.summary()

# Optimizasyon
optimizer = Adam(learning_rate=0.0001)
model.compile(loss='mean_squared_error', optimizer=optimizer)

# Callback'ler
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode="min"),
    ModelCheckpoint(filepath='tuprsao.h5', monitor='val_loss', mode='min',
                    save_best_only=True, save_weights_only=False, verbose=1)
]

# Model eğitimi
history = model.fit(
    x=X_train,
    y=Y_train,
    epochs=500,
    batch_size=32,
    validation_data=(X_test, Y_test),
    callbacks=callbacks,
    shuffle=False
)

# Eğitim ve doğrulama kaybını görselleştirme
plt.figure(figsize=(20,5))
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.legend(loc='upper right')
plt.xlabel('Epok', fontsize=16)
plt.ylabel('Kayıp', fontsize=16)
plt.ylim([0,max(plt.ylim())])
plt.title('Eğitim ve Doğrulama Kaybı', fontsize=16)
plt.show()

# Model değerlendirme
loss = model.evaluate(X_test, Y_test, batch_size=32)
print("\nTest kaybı: %.1f%%" % (100.0 * loss))
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
train_predict = scaler_train.inverse_transform(train_predict)
test_predict = scaler_test.inverse_transform(test_predict)
Y_train = scaler_train.inverse_transform(Y_train)
Y_test = scaler_test.inverse_transform(Y_test)


# Tahminleri görselleştirme
train_prediction_df = result_df[lookback:pos]
train_prediction_df["Tahmin Edilen"] = train_predict
test_prediction_df = result_df[pos+lookback:]
test_prediction_df["Tahmin Edilen"] = test_predict

plt.figure(figsize=(14,5))
plt.plot(result_df, label='Gerçek Değerler')
plt.plot(train_prediction_df["Tahmin Edilen"], color='blue', label='Eğitim Tahmini')
plt.plot(test_prediction_df["Tahmin Edilen"], color="red", label='Test Tahmini')
plt.xlabel('Zaman')
plt.ylabel('Fiyat')
plt.title('tuprs GRAFİĞİ')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\musab\AppData\Local\Temp\ipykernel_13232\1998331396.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tuprsao_df.drop("Date", axis=1, inplace=True)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 20)             820
#
#  dropout (Dropout)           (None, 1, 20)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 10)                310
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 1,141
# Trainable params: 1,141
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0670
# Epoch 1: val_loss improved from inf to 0.10304, saving model to tuprsao.h5
# 64/64 [==============================] - 4s 20ms/step - loss: 0.0710 - val_loss: 0.1030
# Epoch 2/500
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0274
# Epoch 2: val_loss improved from 0.10304 to 0.06404, saving model to tuprsao.h5
# 64/64 [==============================] - 1s 12ms/step - loss: 0.0361 - val_loss: 0.0640
# Epoch 3/500
# 59/64 [==========================>...] - ETA: 0s - loss: 0.0197
# Epoch 3: val_loss improved from 0.06404 to 0.04206, saving model to tuprsao.h5
# 64/64 [==============================] - 1s 12ms/step - loss: 0.0270 - val_loss: 0.0421
# Epoch 4/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0179
# Epoch 4: val_loss improved from 0.04206 to 0.02826, saving model to tuprsao.h5
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0193 - val_loss: 0.0283
# Epoch 5/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0147
# Epoch 5: val_loss improved from 0.02826 to 0.01998, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0184 - val_loss: 0.0200
# Epoch 6/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0156
# Epoch 6: val_loss improved from 0.01998 to 0.01506, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0156 - val_loss: 0.0151
# Epoch 7/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0122
# Epoch 7: val_loss improved from 0.01506 to 0.01221, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0144 - val_loss: 0.0122
# Epoch 8/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0119
# Epoch 8: val_loss improved from 0.01221 to 0.01058, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0136 - val_loss: 0.0106
# Epoch 9/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0128
# Epoch 9: val_loss improved from 0.01058 to 0.00931, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0138 - val_loss: 0.0093
# Epoch 10/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 10: val_loss improved from 0.00931 to 0.00854, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0144 - val_loss: 0.0085
# Epoch 11/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0114
# Epoch 11: val_loss improved from 0.00854 to 0.00799, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0123 - val_loss: 0.0080
# Epoch 12/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0103
# Epoch 12: val_loss did not improve from 0.00799
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0116 - val_loss: 0.0080
# Epoch 13/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 13: val_loss improved from 0.00799 to 0.00749, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0112 - val_loss: 0.0075
# Epoch 14/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0099
# Epoch 14: val_loss improved from 0.00749 to 0.00705, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0105 - val_loss: 0.0070
# Epoch 15/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0102
# Epoch 15: val_loss did not improve from 0.00705
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0118 - val_loss: 0.0071
# Epoch 16/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0105
# Epoch 16: val_loss improved from 0.00705 to 0.00659, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 30ms/step - loss: 0.0105 - val_loss: 0.0066
# Epoch 17/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0099
# Epoch 17: val_loss did not improve from 0.00659
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0099 - val_loss: 0.0066
# Epoch 18/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 18: val_loss improved from 0.00659 to 0.00647, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0093 - val_loss: 0.0065
# Epoch 19/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 19: val_loss improved from 0.00647 to 0.00634, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 30ms/step - loss: 0.0091 - val_loss: 0.0063
# Epoch 20/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 20: val_loss improved from 0.00634 to 0.00594, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0083 - val_loss: 0.0059
# Epoch 21/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 21: val_loss did not improve from 0.00594
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0093 - val_loss: 0.0060
# Epoch 22/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 22: val_loss improved from 0.00594 to 0.00563, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0091 - val_loss: 0.0056
# Epoch 23/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 23: val_loss improved from 0.00563 to 0.00552, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0077 - val_loss: 0.0055
# Epoch 24/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 24: val_loss improved from 0.00552 to 0.00524, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0085 - val_loss: 0.0052
# Epoch 25/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0075
# Epoch 25: val_loss improved from 0.00524 to 0.00518, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0082 - val_loss: 0.0052
# Epoch 26/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 26: val_loss improved from 0.00518 to 0.00478, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0092 - val_loss: 0.0048
# Epoch 27/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 27: val_loss did not improve from 0.00478
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0078 - val_loss: 0.0049
# Epoch 28/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 28: val_loss did not improve from 0.00478
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0076 - val_loss: 0.0051
# Epoch 29/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 29: val_loss did not improve from 0.00478
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 30/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 30: val_loss did not improve from 0.00478
# 64/64 [==============================] - 2s 24ms/step - loss: 0.0062 - val_loss: 0.0048
# Epoch 31/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 31: val_loss improved from 0.00478 to 0.00445, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0078 - val_loss: 0.0044
# Epoch 32/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 32: val_loss improved from 0.00445 to 0.00429, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0068 - val_loss: 0.0043
# Epoch 33/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 33: val_loss did not improve from 0.00429
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0078 - val_loss: 0.0046
# Epoch 34/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0057
# Epoch 34: val_loss improved from 0.00429 to 0.00425, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0061 - val_loss: 0.0043
# Epoch 35/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 35: val_loss improved from 0.00425 to 0.00420, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0059 - val_loss: 0.0042
# Epoch 36/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0058
# Epoch 36: val_loss did not improve from 0.00420
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0067 - val_loss: 0.0043
# Epoch 37/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 37: val_loss improved from 0.00420 to 0.00388, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0057 - val_loss: 0.0039
# Epoch 38/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0061
# Epoch 38: val_loss did not improve from 0.00388
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0064 - val_loss: 0.0041
# Epoch 39/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 39: val_loss did not improve from 0.00388
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0055 - val_loss: 0.0040
# Epoch 40/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 40: val_loss did not improve from 0.00388
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0063 - val_loss: 0.0042
# Epoch 41/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 41: val_loss improved from 0.00388 to 0.00368, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0056 - val_loss: 0.0037
# Epoch 42/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 42: val_loss did not improve from 0.00368
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0059 - val_loss: 0.0037
# Epoch 43/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 43: val_loss improved from 0.00368 to 0.00365, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0052 - val_loss: 0.0036
# Epoch 44/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 44: val_loss improved from 0.00365 to 0.00358, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0055 - val_loss: 0.0036
# Epoch 45/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 45: val_loss did not improve from 0.00358
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0050 - val_loss: 0.0037
# Epoch 46/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 46: val_loss did not improve from 0.00358
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0050 - val_loss: 0.0038
# Epoch 47/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0042
# Epoch 47: val_loss did not improve from 0.00358
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0051 - val_loss: 0.0037
# Epoch 48/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 48: val_loss improved from 0.00358 to 0.00358, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0051 - val_loss: 0.0036
# Epoch 49/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0050
# Epoch 49: val_loss improved from 0.00358 to 0.00344, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 50/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 50: val_loss did not improve from 0.00344
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0048 - val_loss: 0.0036
# Epoch 51/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 51: val_loss improved from 0.00344 to 0.00309, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0055 - val_loss: 0.0031
# Epoch 52/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0045
# Epoch 52: val_loss did not improve from 0.00309
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0052 - val_loss: 0.0033
# Epoch 53/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 53: val_loss did not improve from 0.00309
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0043 - val_loss: 0.0034
# Epoch 54/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 54: val_loss did not improve from 0.00309
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 55/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 55: val_loss did not improve from 0.00309
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0052 - val_loss: 0.0033
# Epoch 56/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 56: val_loss improved from 0.00309 to 0.00304, saving model to tuprsao.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0046 - val_loss: 0.0030
# Epoch 57/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 57: val_loss did not improve from 0.00304
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0044 - val_loss: 0.0031
# Epoch 58/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 58: val_loss did not improve from 0.00304
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0047 - val_loss: 0.0033
# Epoch 59/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 59: val_loss did not improve from 0.00304
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0044 - val_loss: 0.0030
# Epoch 60/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 60: val_loss did not improve from 0.00304
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 61/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 61: val_loss did not improve from 0.00304
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0046 - val_loss: 0.0031
# Epoch 61: early stopping
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0031
#
# Test kaybı: 0.3%
# 64/64 [==============================] - 1s 7ms/step
# 16/16 [==============================] - 0s 6ms/step
# C:\Users\musab\AppData\Local\Temp\ipykernel_13232\1998331396.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_prediction_df["Tahmin Edilen"] = train_predict
# C:\Users\musab\AppData\Local\Temp\ipykernel_13232\1998331396.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_prediction_df["Tahmin Edilen"] = test_predict

# %%
#MAE hesaplama
train_mae = mean_absolute_error(Y_train, train_predict)
test_mae = mean_absolute_error(Y_test, test_predict)
print(f"Eğitim MAE: {train_mae}")
print(f"Test MAE: {test_mae}")

#MAPE hesaplama
train_mape = mean_absolute_percentage_error(Y_train, train_predict) * 100
test_mape = mean_absolute_percentage_error(Y_test, test_predict) * 100
print(f"Eğitim MAPE: {train_mape}%")
print(f"Test MAPE: {test_mape}%")

#RMSE hesaplama
train_rmse = np.sqrt(mean_squared_error(Y_train, train_predict))
test_rmse = np.sqrt(mean_squared_error(Y_test, test_predict))
print(f"Eğitim RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Eğitim MAE: 0.6841089725494385
# Test MAE: 7.067634105682373
# Eğitim MAPE: 4.5729778707027435%
# Test MAPE: 6.864159554243088%
# Eğitim RMSE: 1.0677640438079834
# Test RMSE: 9.482560157775879
