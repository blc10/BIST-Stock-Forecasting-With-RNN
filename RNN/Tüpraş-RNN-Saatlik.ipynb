# %%
import yfinance as yf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# Veriyi indirme ve inceleme
ticker_symbol = 'TUPRS.IS'
start_date = '2022-05-10'
end_date = '2024-04-10'
df = yf.download(ticker_symbol, period="2y", interval="60m")
df['Date'] = pd.to_datetime(df.index)


# Veri hazırlama
df["Date"] = pd.to_datetime(df["Date"])
tuprsao_df = df[["Date", "Close"]]
tuprsao_df.index = tuprsao_df["Date"]
tuprsao_df.drop("Date", axis=1, inplace=True)
result_df = tuprsao_df.copy()
plt.figure(figsize=(12,6))
plt.plot(tuprsao_df['Close'], color='blue')
plt.ylabel('Fiyat')
plt.title('tuprsao Grafiği')
plt.xlabel('Zaman')
plt.show()

# Veri önişleme
tuprsao_df = tuprsao_df.values.astype('float32')
def split_data(dataframe, test_size):
    pos = int(round(len(dataframe) * (1 - test_size)))
    train = dataframe[:pos]
    test = dataframe[pos:]
    return train, test, pos

train, test, pos = split_data(tuprsao_df, 0.20)
scaler_train = MinMaxScaler(feature_range=(0, 1))
train = scaler_train.fit_transform(train)
scaler_test = MinMaxScaler(feature_range=(0, 1))
test = scaler_test.fit_transform(test)

def create_features(data, lookback):
    X, Y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i-lookback:i, 0])
        Y.append(data[i, 0])
    return np.array(X), np.array(Y)

lookback = 40
X_train, Y_train = create_features(train, lookback)
X_test, Y_test = create_features(test, lookback)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
Y_train = Y_train.reshape(-1, 1)
Y_test = Y_test.reshape(-1, 1)

# Model oluşturma
model = Sequential([
    SimpleRNN(units=20, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], lookback)),
    Dropout(0.1),
    SimpleRNN(units=10, activation='relu'),
    Dropout(0.1),
    Dense(1)
])


model.summary()

# Optimizasyon
optimizer = Adam(learning_rate=0.0001)
model.compile(loss='mean_squared_error', optimizer=optimizer)

# Callback'ler
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode="min"),
    ModelCheckpoint(filepath='tuprsao.h5', monitor='val_loss', mode='min',
                    save_best_only=True, save_weights_only=False, verbose=1)
]

# Model eğitimi
history = model.fit(
    x=X_train,
    y=Y_train,
    epochs=500,
    batch_size=32,
    validation_data=(X_test, Y_test),
    callbacks=callbacks,
    shuffle=False
)

# Eğitim ve doğrulama kaybını görselleştirme
plt.figure(figsize=(20,5))
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.legend(loc='upper right')
plt.xlabel('Epok', fontsize=16)
plt.ylabel('Kayıp', fontsize=16)
plt.ylim([0,max(plt.ylim())])
plt.title('Eğitim ve Doğrulama Kaybı', fontsize=16)
plt.show()

# Model değerlendirme
loss = model.evaluate(X_test, Y_test, batch_size=32)
print("\nTest kaybı: %.1f%%" % (100.0 * loss))
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
train_predict = scaler_train.inverse_transform(train_predict)
test_predict = scaler_test.inverse_transform(test_predict)
Y_train = scaler_train.inverse_transform(Y_train)
Y_test = scaler_test.inverse_transform(Y_test)


# Tahminleri görselleştirme
train_prediction_df = result_df[lookback:pos]
train_prediction_df["Tahmin Edilen"] = train_predict
test_prediction_df = result_df[pos+lookback:]
test_prediction_df["Tahmin Edilen"] = test_predict

plt.figure(figsize=(14,5))
plt.plot(result_df, label='Gerçek Değerler')
plt.plot(train_prediction_df["Tahmin Edilen"], color='blue', label='Eğitim Tahmini')
plt.plot(test_prediction_df["Tahmin Edilen"], color="red", label='Test Tahmini')
plt.xlabel('Zaman')
plt.ylabel('Fiyat')
plt.title('tuprs GRAFİĞİ')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\musab\AppData\Local\Temp\ipykernel_5540\3724291016.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tuprsao_df.drop("Date", axis=1, inplace=True)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 20)             1220
#
#  dropout (Dropout)           (None, 1, 20)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 10)                310
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 1,541
# Trainable params: 1,541
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 103/105 [============================>.] - ETA: 0s - loss: 0.2567
# Epoch 1: val_loss improved from inf to 0.14663, saving model to tuprsao.h5
# 105/105 [==============================] - 4s 16ms/step - loss: 0.2609 - val_loss: 0.1466
# Epoch 2/500
# 103/105 [============================>.] - ETA: 0s - loss: 0.0943
# Epoch 2: val_loss improved from 0.14663 to 0.05819, saving model to tuprsao.h5
# 105/105 [==============================] - 1s 13ms/step - loss: 0.0972 - val_loss: 0.0582
# Epoch 3/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0680
# Epoch 3: val_loss improved from 0.05819 to 0.03506, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0679 - val_loss: 0.0351
# Epoch 4/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0527
# Epoch 4: val_loss improved from 0.03506 to 0.02224, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0539 - val_loss: 0.0222
# Epoch 5/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0479
# Epoch 5: val_loss improved from 0.02224 to 0.01539, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0482 - val_loss: 0.0154
# Epoch 6/500
# 103/105 [============================>.] - ETA: 0s - loss: 0.0380
# Epoch 6: val_loss improved from 0.01539 to 0.01265, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0398 - val_loss: 0.0126
# Epoch 7/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0361
# Epoch 7: val_loss improved from 0.01265 to 0.01195, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 29ms/step - loss: 0.0361 - val_loss: 0.0120
# Epoch 8/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0359
# Epoch 8: val_loss did not improve from 0.01195
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0359 - val_loss: 0.0120
# Epoch 9/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0323
# Epoch 9: val_loss did not improve from 0.01195
# 105/105 [==============================] - 3s 29ms/step - loss: 0.0325 - val_loss: 0.0126
# Epoch 10/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0271
# Epoch 10: val_loss did not improve from 0.01195
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0275 - val_loss: 0.0121
# Epoch 11/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0270
# Epoch 11: val_loss improved from 0.01195 to 0.01042, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0273 - val_loss: 0.0104
# Epoch 12/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0224
# Epoch 12: val_loss improved from 0.01042 to 0.00912, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0224 - val_loss: 0.0091
# Epoch 13/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0240
# Epoch 13: val_loss improved from 0.00912 to 0.00852, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0242 - val_loss: 0.0085
# Epoch 14/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0234
# Epoch 14: val_loss improved from 0.00852 to 0.00809, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 29ms/step - loss: 0.0234 - val_loss: 0.0081
# Epoch 15/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0231
# Epoch 15: val_loss improved from 0.00809 to 0.00803, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0231 - val_loss: 0.0080
# Epoch 16/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0193
# Epoch 16: val_loss improved from 0.00803 to 0.00773, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0196 - val_loss: 0.0077
# Epoch 17/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0222
# Epoch 17: val_loss did not improve from 0.00773
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0224 - val_loss: 0.0081
# Epoch 18/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0198
# Epoch 18: val_loss improved from 0.00773 to 0.00734, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0202 - val_loss: 0.0073
# Epoch 19/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0240
# Epoch 19: val_loss did not improve from 0.00734
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0240 - val_loss: 0.0076
# Epoch 20/500
# 103/105 [============================>.] - ETA: 0s - loss: 0.0202
# Epoch 20: val_loss improved from 0.00734 to 0.00692, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0205 - val_loss: 0.0069
# Epoch 21/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0176
# Epoch 21: val_loss did not improve from 0.00692
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0177 - val_loss: 0.0073
# Epoch 22/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0184
# Epoch 22: val_loss improved from 0.00692 to 0.00679, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 31ms/step - loss: 0.0184 - val_loss: 0.0068
# Epoch 23/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 23: val_loss did not improve from 0.00679
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0165 - val_loss: 0.0069
# Epoch 24/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0156
# Epoch 24: val_loss improved from 0.00679 to 0.00667, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0159 - val_loss: 0.0067
# Epoch 25/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 25: val_loss improved from 0.00667 to 0.00658, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0162 - val_loss: 0.0066
# Epoch 26/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0150
# Epoch 26: val_loss did not improve from 0.00658
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0153 - val_loss: 0.0069
# Epoch 27/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0149
# Epoch 27: val_loss did not improve from 0.00658
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0149 - val_loss: 0.0067
# Epoch 28/500
# 103/105 [============================>.] - ETA: 0s - loss: 0.0130
# Epoch 28: val_loss improved from 0.00658 to 0.00653, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0137 - val_loss: 0.0065
# Epoch 29/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 29: val_loss improved from 0.00653 to 0.00613, saving model to tuprsao.h5
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0147 - val_loss: 0.0061
# Epoch 30/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 30: val_loss did not improve from 0.00613
# 105/105 [==============================] - 3s 30ms/step - loss: 0.0152 - val_loss: 0.0063
# Epoch 31/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0116
# Epoch 31: val_loss did not improve from 0.00613
# 105/105 [==============================] - 4s 34ms/step - loss: 0.0117 - val_loss: 0.0068
# Epoch 32/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 32: val_loss did not improve from 0.00613
# 105/105 [==============================] - 4s 34ms/step - loss: 0.0112 - val_loss: 0.0073
# Epoch 33/500
# 104/105 [============================>.] - ETA: 0s - loss: 0.0124
# Epoch 33: val_loss did not improve from 0.00613
# 105/105 [==============================] - 4s 35ms/step - loss: 0.0125 - val_loss: 0.0067
# Epoch 34/500
# 105/105 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 34: val_loss did not improve from 0.00613
# 105/105 [==============================] - 3s 32ms/step - loss: 0.0107 - val_loss: 0.0064
# Epoch 34: early stopping
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0064
#
# Test kaybı: 0.6%
# 105/105 [==============================] - 1s 7ms/step
# 26/26 [==============================] - 0s 7ms/step
# C:\Users\musab\AppData\Local\Temp\ipykernel_5540\3724291016.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_prediction_df["Tahmin Edilen"] = train_predict
# C:\Users\musab\AppData\Local\Temp\ipykernel_5540\3724291016.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_prediction_df["Tahmin Edilen"] = test_predict

# %%
#MAE hesaplama
train_mae = mean_absolute_error(Y_train, train_predict)
test_mae = mean_absolute_error(Y_test, test_predict)
print(f"Eğitim MAE: {train_mae}")
print(f"Test MAE: {test_mae}")

#MAPE hesaplama
train_mape = mean_absolute_percentage_error(Y_train, train_predict) * 100
test_mape = mean_absolute_percentage_error(Y_test, test_predict) * 100
print(f"Eğitim MAPE: {train_mape}%")
print(f"Test MAPE: {test_mape}%")

#RMSE hesaplama
train_rmse = np.sqrt(mean_squared_error(Y_train, train_predict))
test_rmse = np.sqrt(mean_squared_error(Y_test, test_predict))
print(f"Eğitim RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Eğitim MAE: 4.948042392730713
# Test MAE: 4.328978538513184
# Eğitim MAPE: 7.882275432348251%
# Test MAPE: 2.600596845149994%
# Eğitim RMSE: 6.397403717041016
# Test RMSE: 5.261958122253418
