# %%
import yfinance as yf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# Veriyi indirme ve inceleme
ticker_symbol = 'TUPRS.IS'
start_date = '2022-05-10'
end_date = '2024-04-10'
df = yf.download(ticker_symbol, period="10y", interval="1wk")
df['Date'] = pd.to_datetime(df.index)


# Veri hazırlama
df["Date"] = pd.to_datetime(df["Date"])
tuprsao_df = df[["Date", "Close"]]
tuprsao_df.index = tuprsao_df["Date"]
tuprsao_df.drop("Date", axis=1, inplace=True)
result_df = tuprsao_df.copy()
plt.figure(figsize=(12,6))
plt.plot(tuprsao_df['Close'], color='blue')
plt.ylabel('Fiyat')
plt.title('tuprsao Grafiği')
plt.xlabel('Zaman')
plt.show()

# Veri önişleme
tuprsao_df = tuprsao_df.values.astype('float32')
def split_data(dataframe, test_size):
    pos = int(round(len(dataframe) * (1 - test_size)))
    train = dataframe[:pos]
    test = dataframe[pos:]
    return train, test, pos

train, test, pos = split_data(tuprsao_df, 0.20)
scaler_train = MinMaxScaler(feature_range=(0, 1))
train = scaler_train.fit_transform(train)
scaler_test = MinMaxScaler(feature_range=(0, 1))
test = scaler_test.fit_transform(test)

def create_features(data, lookback):
    X, Y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i-lookback:i, 0])
        Y.append(data[i, 0])
    return np.array(X), np.array(Y)

lookback = 4
X_train, Y_train = create_features(train, lookback)
X_test, Y_test = create_features(test, lookback)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
Y_train = Y_train.reshape(-1, 1)
Y_test = Y_test.reshape(-1, 1)

# Model oluşturma
model = Sequential([
    SimpleRNN(units=20, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], lookback)),
    Dropout(0.1),
    SimpleRNN(units=10, activation='relu'),
    Dropout(0.1),
    Dense(1)
])


model.summary()

# Optimizasyon
optimizer = Adam(learning_rate=0.0001)
model.compile(loss='mean_squared_error', optimizer=optimizer)

# Callback'ler
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode="min"),
    ModelCheckpoint(filepath='tuprsao.h5', monitor='val_loss', mode='min',
                    save_best_only=True, save_weights_only=False, verbose=1)
]

# Model eğitimi
history = model.fit(
    x=X_train,
    y=Y_train,
    epochs=500,
    batch_size=32,
    validation_data=(X_test, Y_test),
    callbacks=callbacks,
    shuffle=False
)

# Eğitim ve doğrulama kaybını görselleştirme
plt.figure(figsize=(20,5))
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.legend(loc='upper right')
plt.xlabel('Epok', fontsize=16)
plt.ylabel('Kayıp', fontsize=16)
plt.ylim([0,max(plt.ylim())])
plt.title('Eğitim ve Doğrulama Kaybı', fontsize=16)
plt.show()

# Model değerlendirme
loss = model.evaluate(X_test, Y_test, batch_size=32)
print("\nTest kaybı: %.1f%%" % (100.0 * loss))
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
train_predict = scaler_train.inverse_transform(train_predict)
test_predict = scaler_test.inverse_transform(test_predict)
Y_train = scaler_train.inverse_transform(Y_train)
Y_test = scaler_test.inverse_transform(Y_test)


# Tahminleri görselleştirme
train_prediction_df = result_df[lookback:pos]
train_prediction_df["Tahmin Edilen"] = train_predict
test_prediction_df = result_df[pos+lookback:]
test_prediction_df["Tahmin Edilen"] = test_predict

plt.figure(figsize=(14,5))
plt.plot(result_df, label='Gerçek Değerler')
plt.plot(train_prediction_df["Tahmin Edilen"], color='blue', label='Eğitim Tahmini')
plt.plot(test_prediction_df["Tahmin Edilen"], color="red", label='Test Tahmini')
plt.xlabel('Zaman')
plt.ylabel('Fiyat')
plt.title('tuprs GRAFİĞİ')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\musab\AppData\Local\Temp\ipykernel_16572\526648449.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tuprsao_df.drop("Date", axis=1, inplace=True)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 20)             500
#
#  dropout (Dropout)           (None, 1, 20)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 10)                310
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 821
# Trainable params: 821
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0564
# Epoch 1: val_loss improved from inf to 0.14450, saving model to tuprsao.h5
# 13/13 [==============================] - 3s 53ms/step - loss: 0.0564 - val_loss: 0.1445
# Epoch 2/500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0347
# Epoch 2: val_loss improved from 0.14450 to 0.13785, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0528 - val_loss: 0.1378
# Epoch 3/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0492
# Epoch 3: val_loss improved from 0.13785 to 0.13136, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0492 - val_loss: 0.1314
# Epoch 4/500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0315
# Epoch 4: val_loss improved from 0.13136 to 0.12508, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0478 - val_loss: 0.1251
# Epoch 5/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 5: val_loss improved from 0.12508 to 0.11899, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0450 - val_loss: 0.1190
# Epoch 6/500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0277
# Epoch 6: val_loss improved from 0.11899 to 0.11311, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0429 - val_loss: 0.1131
# Epoch 7/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0421
# Epoch 7: val_loss improved from 0.11311 to 0.10764, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0421 - val_loss: 0.1076
# Epoch 8/500
#  8/13 [=================>............] - ETA: 0s - loss: 0.0201
# Epoch 8: val_loss improved from 0.10764 to 0.10240, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0389 - val_loss: 0.1024
# Epoch 9/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0367
# Epoch 9: val_loss improved from 0.10240 to 0.09743, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0367 - val_loss: 0.0974
# Epoch 10/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0213
# Epoch 10: val_loss improved from 0.09743 to 0.09278, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0339 - val_loss: 0.0928
# Epoch 11/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0193
# Epoch 11: val_loss improved from 0.09278 to 0.08836, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0320 - val_loss: 0.0884
# Epoch 12/500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0165
# Epoch 12: val_loss improved from 0.08836 to 0.08409, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0273 - val_loss: 0.0841
# Epoch 13/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0172
# Epoch 13: val_loss improved from 0.08409 to 0.07999, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0280 - val_loss: 0.0800
# Epoch 14/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0158
# Epoch 14: val_loss improved from 0.07999 to 0.07607, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0262 - val_loss: 0.0761
# Epoch 15/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0261
# Epoch 15: val_loss improved from 0.07607 to 0.07238, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0261 - val_loss: 0.0724
# Epoch 16/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0147
# Epoch 16: val_loss improved from 0.07238 to 0.06875, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0243 - val_loss: 0.0687
# Epoch 17/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0222
# Epoch 17: val_loss improved from 0.06875 to 0.06531, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0222 - val_loss: 0.0653
# Epoch 18/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0203
# Epoch 18: val_loss improved from 0.06531 to 0.06207, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0203 - val_loss: 0.0621
# Epoch 19/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0133
# Epoch 19: val_loss improved from 0.06207 to 0.05905, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0233 - val_loss: 0.0590
# Epoch 20/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0113
# Epoch 20: val_loss improved from 0.05905 to 0.05628, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0183 - val_loss: 0.0563
# Epoch 21/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0094
# Epoch 21: val_loss improved from 0.05628 to 0.05370, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0176 - val_loss: 0.0537
# Epoch 22/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0094
# Epoch 22: val_loss improved from 0.05370 to 0.05121, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0173 - val_loss: 0.0512
# Epoch 23/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0203
# Epoch 23: val_loss improved from 0.05121 to 0.04891, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0203 - val_loss: 0.0489
# Epoch 24/500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0093
# Epoch 24: val_loss improved from 0.04891 to 0.04666, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0158 - val_loss: 0.0467
# Epoch 25/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0096
# Epoch 25: val_loss improved from 0.04666 to 0.04453, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0184 - val_loss: 0.0445
# Epoch 26/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0144
# Epoch 26: val_loss improved from 0.04453 to 0.04257, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0144 - val_loss: 0.0426
# Epoch 27/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 27: val_loss improved from 0.04257 to 0.04075, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0167 - val_loss: 0.0408
# Epoch 28/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 28: val_loss improved from 0.04075 to 0.03897, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0141 - val_loss: 0.0390
# Epoch 29/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0117
# Epoch 29: val_loss improved from 0.03897 to 0.03739, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0117 - val_loss: 0.0374
# Epoch 30/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 30: val_loss improved from 0.03739 to 0.03597, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0129 - val_loss: 0.0360
# Epoch 31/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 31: val_loss improved from 0.03597 to 0.03463, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0140 - val_loss: 0.0346
# Epoch 32/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 32: val_loss improved from 0.03463 to 0.03331, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0131 - val_loss: 0.0333
# Epoch 33/500
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0063
# Epoch 33: val_loss improved from 0.03331 to 0.03216, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0110 - val_loss: 0.0322
# Epoch 34/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0122
# Epoch 34: val_loss improved from 0.03216 to 0.03103, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0122 - val_loss: 0.0310
# Epoch 35/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 35: val_loss improved from 0.03103 to 0.02997, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0104 - val_loss: 0.0300
# Epoch 36/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0100
# Epoch 36: val_loss improved from 0.02997 to 0.02892, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0100 - val_loss: 0.0289
# Epoch 37/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 37: val_loss improved from 0.02892 to 0.02800, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0097 - val_loss: 0.0280
# Epoch 38/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0115
# Epoch 38: val_loss improved from 0.02800 to 0.02712, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0115 - val_loss: 0.0271
# Epoch 39/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0116
# Epoch 39: val_loss improved from 0.02712 to 0.02628, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0116 - val_loss: 0.0263
# Epoch 40/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0105
# Epoch 40: val_loss improved from 0.02628 to 0.02554, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0105 - val_loss: 0.0255
# Epoch 41/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0118
# Epoch 41: val_loss improved from 0.02554 to 0.02481, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0118 - val_loss: 0.0248
# Epoch 42/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 42: val_loss improved from 0.02481 to 0.02411, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0103 - val_loss: 0.0241
# Epoch 43/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0084
# Epoch 43: val_loss improved from 0.02411 to 0.02352, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0084 - val_loss: 0.0235
# Epoch 44/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0100
# Epoch 44: val_loss improved from 0.02352 to 0.02297, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0100 - val_loss: 0.0230
# Epoch 45/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0097
# Epoch 45: val_loss improved from 0.02297 to 0.02241, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0097 - val_loss: 0.0224
# Epoch 46/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 46: val_loss improved from 0.02241 to 0.02185, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0091 - val_loss: 0.0218
# Epoch 47/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0125
# Epoch 47: val_loss improved from 0.02185 to 0.02134, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0125 - val_loss: 0.0213
# Epoch 48/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 48: val_loss improved from 0.02134 to 0.02073, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0101 - val_loss: 0.0207
# Epoch 49/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 49: val_loss improved from 0.02073 to 0.02023, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0082 - val_loss: 0.0202
# Epoch 50/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 50: val_loss improved from 0.02023 to 0.01983, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0077 - val_loss: 0.0198
# Epoch 51/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 51: val_loss improved from 0.01983 to 0.01948, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0077 - val_loss: 0.0195
# Epoch 52/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0059
# Epoch 52: val_loss improved from 0.01948 to 0.01912, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0090 - val_loss: 0.0191
# Epoch 53/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 53: val_loss improved from 0.01912 to 0.01870, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0081 - val_loss: 0.0187
# Epoch 54/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 54: val_loss improved from 0.01870 to 0.01831, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0081 - val_loss: 0.0183
# Epoch 55/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0098
# Epoch 55: val_loss improved from 0.01831 to 0.01798, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0098 - val_loss: 0.0180
# Epoch 56/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 56: val_loss improved from 0.01798 to 0.01761, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0086 - val_loss: 0.0176
# Epoch 57/500
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0060
# Epoch 57: val_loss improved from 0.01761 to 0.01725, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0087 - val_loss: 0.0173
# Epoch 58/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 58: val_loss improved from 0.01725 to 0.01696, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0073 - val_loss: 0.0170
# Epoch 59/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 59: val_loss improved from 0.01696 to 0.01672, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0088 - val_loss: 0.0167
# Epoch 60/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0117
# Epoch 60: val_loss improved from 0.01672 to 0.01646, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0117 - val_loss: 0.0165
# Epoch 61/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0039
# Epoch 61: val_loss improved from 0.01646 to 0.01616, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0079 - val_loss: 0.0162
# Epoch 62/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 62: val_loss improved from 0.01616 to 0.01584, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0082 - val_loss: 0.0158
# Epoch 63/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0094
# Epoch 63: val_loss improved from 0.01584 to 0.01558, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0094 - val_loss: 0.0156
# Epoch 64/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 64: val_loss improved from 0.01558 to 0.01532, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0092 - val_loss: 0.0153
# Epoch 65/500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0042
# Epoch 65: val_loss improved from 0.01532 to 0.01508, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0095 - val_loss: 0.0151
# Epoch 66/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 66: val_loss improved from 0.01508 to 0.01483, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0073 - val_loss: 0.0148
# Epoch 67/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0044
# Epoch 67: val_loss improved from 0.01483 to 0.01463, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0097 - val_loss: 0.0146
# Epoch 68/500
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0051
# Epoch 68: val_loss improved from 0.01463 to 0.01438, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0090 - val_loss: 0.0144
# Epoch 69/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 69: val_loss improved from 0.01438 to 0.01416, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0101 - val_loss: 0.0142
# Epoch 70/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 70: val_loss improved from 0.01416 to 0.01388, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0087 - val_loss: 0.0139
# Epoch 71/500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0043
# Epoch 71: val_loss improved from 0.01388 to 0.01368, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0071 - val_loss: 0.0137
# Epoch 72/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 72: val_loss improved from 0.01368 to 0.01352, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0058 - val_loss: 0.0135
# Epoch 73/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 73: val_loss improved from 0.01352 to 0.01340, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0073 - val_loss: 0.0134
# Epoch 74/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 74: val_loss improved from 0.01340 to 0.01323, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0063 - val_loss: 0.0132
# Epoch 75/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 75: val_loss improved from 0.01323 to 0.01309, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0077 - val_loss: 0.0131
# Epoch 76/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0040
# Epoch 76: val_loss improved from 0.01309 to 0.01295, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0054 - val_loss: 0.0129
# Epoch 77/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 77: val_loss improved from 0.01295 to 0.01283, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0075 - val_loss: 0.0128
# Epoch 78/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 78: val_loss improved from 0.01283 to 0.01271, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0056 - val_loss: 0.0127
# Epoch 79/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 79: val_loss improved from 0.01271 to 0.01268, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0057 - val_loss: 0.0127
# Epoch 80/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 80: val_loss improved from 0.01268 to 0.01253, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0075 - val_loss: 0.0125
# Epoch 81/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 81: val_loss improved from 0.01253 to 0.01231, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0076 - val_loss: 0.0123
# Epoch 82/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 82: val_loss improved from 0.01231 to 0.01212, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0073 - val_loss: 0.0121
# Epoch 83/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 83: val_loss improved from 0.01212 to 0.01199, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0064 - val_loss: 0.0120
# Epoch 84/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 84: val_loss improved from 0.01199 to 0.01188, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0088 - val_loss: 0.0119
# Epoch 85/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 85: val_loss improved from 0.01188 to 0.01170, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0080 - val_loss: 0.0117
# Epoch 86/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0067
# Epoch 86: val_loss improved from 0.01170 to 0.01150, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0067 - val_loss: 0.0115
# Epoch 87/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 87: val_loss improved from 0.01150 to 0.01135, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0064 - val_loss: 0.0113
# Epoch 88/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 88: val_loss improved from 0.01135 to 0.01132, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0068 - val_loss: 0.0113
# Epoch 89/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 89: val_loss improved from 0.01132 to 0.01121, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0066 - val_loss: 0.0112
# Epoch 90/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0038
# Epoch 90: val_loss improved from 0.01121 to 0.01105, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0066 - val_loss: 0.0110
# Epoch 91/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 91: val_loss improved from 0.01105 to 0.01090, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0060 - val_loss: 0.0109
# Epoch 92/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0037
# Epoch 92: val_loss improved from 0.01090 to 0.01076, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0057 - val_loss: 0.0108
# Epoch 93/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0037
# Epoch 93: val_loss improved from 0.01076 to 0.01075, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0053 - val_loss: 0.0108
# Epoch 94/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 94: val_loss improved from 0.01075 to 0.01069, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0054 - val_loss: 0.0107
# Epoch 95/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 95: val_loss improved from 0.01069 to 0.01055, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0056 - val_loss: 0.0106
# Epoch 96/500
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0032
# Epoch 96: val_loss improved from 0.01055 to 0.01042, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0054 - val_loss: 0.0104
# Epoch 97/500
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0042
# Epoch 97: val_loss improved from 0.01042 to 0.01021, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0066 - val_loss: 0.0102
# Epoch 98/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 98: val_loss improved from 0.01021 to 0.00991, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0049 - val_loss: 0.0099
# Epoch 99/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 99: val_loss improved from 0.00991 to 0.00975, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0047 - val_loss: 0.0097
# Epoch 100/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0074
# Epoch 100: val_loss improved from 0.00975 to 0.00957, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0074 - val_loss: 0.0096
# Epoch 101/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 101: val_loss improved from 0.00957 to 0.00938, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0076 - val_loss: 0.0094
# Epoch 102/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 102: val_loss did not improve from 0.00938
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0049 - val_loss: 0.0094
# Epoch 103/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 103: val_loss did not improve from 0.00938
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0044 - val_loss: 0.0094
# Epoch 104/500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0038
# Epoch 104: val_loss improved from 0.00938 to 0.00938, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0074 - val_loss: 0.0094
# Epoch 105/500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0035
# Epoch 105: val_loss improved from 0.00938 to 0.00914, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0047 - val_loss: 0.0091
# Epoch 106/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0037
# Epoch 106: val_loss improved from 0.00914 to 0.00884, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0059 - val_loss: 0.0088
# Epoch 107/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 107: val_loss improved from 0.00884 to 0.00848, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0060 - val_loss: 0.0085
# Epoch 108/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 108: val_loss improved from 0.00848 to 0.00816, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0058 - val_loss: 0.0082
# Epoch 109/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0033
# Epoch 109: val_loss improved from 0.00816 to 0.00810, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0065 - val_loss: 0.0081
# Epoch 110/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 110: val_loss improved from 0.00810 to 0.00800, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0052 - val_loss: 0.0080
# Epoch 111/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 111: val_loss improved from 0.00800 to 0.00796, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0045 - val_loss: 0.0080
# Epoch 112/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 112: val_loss did not improve from 0.00796
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0054 - val_loss: 0.0080
# Epoch 113/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 113: val_loss improved from 0.00796 to 0.00794, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0047 - val_loss: 0.0079
# Epoch 114/500
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0036
# Epoch 114: val_loss improved from 0.00794 to 0.00783, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 115/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 115: val_loss improved from 0.00783 to 0.00764, saving model to tuprsao.h5
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0047 - val_loss: 0.0076
# Epoch 116/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 116: val_loss did not improve from 0.00764
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0042 - val_loss: 0.0077
# Epoch 117/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0035
# Epoch 117: val_loss did not improve from 0.00764
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0050 - val_loss: 0.0078
# Epoch 118/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 118: val_loss did not improve from 0.00764
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0054 - val_loss: 0.0079
# Epoch 119/500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0028
# Epoch 119: val_loss did not improve from 0.00764
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0049 - val_loss: 0.0077
# Epoch 120/500
# 13/13 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 120: val_loss did not improve from 0.00764
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 120: early stopping
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0077
#
# Test kaybı: 0.8%
# 13/13 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# C:\Users\musab\AppData\Local\Temp\ipykernel_16572\526648449.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_prediction_df["Tahmin Edilen"] = train_predict
# C:\Users\musab\AppData\Local\Temp\ipykernel_16572\526648449.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_prediction_df["Tahmin Edilen"] = test_predict

# %%
#MAE hesaplama
train_mae = mean_absolute_error(Y_train, train_predict)
test_mae = mean_absolute_error(Y_test, test_predict)
print(f"Eğitim MAE: {train_mae}")
print(f"Test MAE: {test_mae}")

#MAPE hesaplama
train_mape = mean_absolute_percentage_error(Y_train, train_predict) * 100
test_mape = mean_absolute_percentage_error(Y_test, test_predict) * 100
print(f"Eğitim MAPE: {train_mape}%")
print(f"Test MAPE: {test_mape}%")

#RMSE hesaplama
train_rmse = np.sqrt(mean_squared_error(Y_train, train_predict))
test_rmse = np.sqrt(mean_squared_error(Y_test, test_predict))
print(f"Eğitim RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Eğitim MAE: 0.8396397829055786
# Test MAE: 11.331268310546875
# Eğitim MAPE: 5.2023746073246%
# Test MAPE: 9.865918010473251%
# Eğitim RMSE: 1.3845393657684326
# Test RMSE: 14.80055046081543
