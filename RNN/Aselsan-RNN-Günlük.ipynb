# %%
import yfinance as yf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# Veriyi indirme ve inceleme
ticker_symbol = 'ASELS.IS'
start_date = '2022-05-10'
end_date = '2024-04-10'
df = yf.download(ticker_symbol, period="10y", interval="1d")
df['Date'] = pd.to_datetime(df.index)

# Veri hazırlama
df["Date"] = pd.to_datetime(df["Date"])
asels_df = df[["Date", "Close"]]
asels_df.index = asels_df["Date"]
asels_df.drop("Date", axis=1, inplace=True)
result_df = asels_df.copy()
plt.figure(figsize=(12,6))
plt.plot(asels_df['Close'], color='blue')
plt.ylabel('Fiyat')
plt.title('Aselsan Grafiği')
plt.xlabel('Zaman')
plt.show()

# Veri önişleme
asels_df = asels_df.values.astype('float32')
def split_data(dataframe, test_size):
    pos = int(round(len(dataframe) * (1 - test_size)))
    train = dataframe[:pos]
    test = dataframe[pos:]
    return train, test, pos

train, test, pos = split_data(asels_df, 0.20)
scaler_train = MinMaxScaler(feature_range=(0, 1))
train = scaler_train.fit_transform(train)
scaler_test = MinMaxScaler(feature_range=(0, 1))
test = scaler_test.fit_transform(test)

def create_features(data, lookback):
    X, Y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i-lookback:i, 0])
        Y.append(data[i, 0])
    return np.array(X), np.array(Y)

lookback = 20
X_train, Y_train = create_features(train, lookback)
X_test, Y_test = create_features(test, lookback)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
Y_train = Y_train.reshape(-1, 1)
Y_test = Y_test.reshape(-1, 1)

# Model oluşturma
model = Sequential([
    SimpleRNN(units=20, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], lookback)),
    Dropout(0.1),
    SimpleRNN(units=10, activation='relu'),
    Dropout(0.1),
    Dense(1)
])


model.summary()

# Optimizasyon
optimizer = Adam(learning_rate=0.0001)
model.compile(loss='mean_squared_error', optimizer=optimizer)

# Callback'ler
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode="min"),
    ModelCheckpoint(filepath='asels.h5', monitor='val_loss', mode='min',
                    save_best_only=True, save_weights_only=False, verbose=1)
]

# Model eğitimi
history = model.fit(
    x=X_train,
    y=Y_train,
    epochs=500,
    batch_size=32,
    validation_data=(X_test, Y_test),
    callbacks=callbacks,
    shuffle=False
)

# Eğitim ve doğrulama kaybını görselleştirme
plt.figure(figsize=(20,5))
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.legend(loc='upper right')
plt.xlabel('Epok', fontsize=16)
plt.ylabel('Kayıp', fontsize=16)
plt.ylim([0,max(plt.ylim())])
plt.title('Eğitim ve Doğrulama Kaybı', fontsize=16)
plt.show()

# Model değerlendirme
loss = model.evaluate(X_test, Y_test, batch_size=32)
print("\nTest kaybı: %.1f%%" % (100.0 * loss))
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
train_predict = scaler_train.inverse_transform(train_predict)
test_predict = scaler_test.inverse_transform(test_predict)
Y_train = scaler_train.inverse_transform(Y_train)
Y_test = scaler_test.inverse_transform(Y_test)


# Tahminleri görselleştirme
train_prediction_df = result_df[lookback:pos]
train_prediction_df["Tahmin Edilen"] = train_predict
test_prediction_df = result_df[pos+lookback:]
test_prediction_df["Tahmin Edilen"] = test_predict

plt.figure(figsize=(14,5))
plt.plot(result_df, label='Gerçek Değerler')
plt.plot(train_prediction_df["Tahmin Edilen"], color='blue', label='Eğitim Tahmini')
plt.plot(test_prediction_df["Tahmin Edilen"], color="red", label='Test Tahmini')
plt.xlabel('Zaman')
plt.ylabel('Fiyat')
plt.title('ASELSAN GRAFİĞİ')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\musab\AppData\Local\Temp\ipykernel_16096\2734381488.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asels_df.drop("Date", axis=1, inplace=True)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 20)             820
#
#  dropout (Dropout)           (None, 1, 20)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 10)                310
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 1,141
# Trainable params: 1,141
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.2252
# Epoch 1: val_loss improved from inf to 0.30517, saving model to asels.h5
# 64/64 [==============================] - 4s 21ms/step - loss: 0.2671 - val_loss: 0.3052
# Epoch 2/500
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1542
# Epoch 2: val_loss improved from 0.30517 to 0.24953, saving model to asels.h5
# 64/64 [==============================] - 1s 14ms/step - loss: 0.1886 - val_loss: 0.2495
# Epoch 3/500
# 61/64 [===========================>..] - ETA: 0s - loss: 0.1275
# Epoch 3: val_loss improved from 0.24953 to 0.20124, saving model to asels.h5
# 64/64 [==============================] - 1s 13ms/step - loss: 0.1472 - val_loss: 0.2012
# Epoch 4/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.1027
# Epoch 4: val_loss improved from 0.20124 to 0.16177, saving model to asels.h5
# 64/64 [==============================] - 1s 22ms/step - loss: 0.1130 - val_loss: 0.1618
# Epoch 5/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0867
# Epoch 5: val_loss improved from 0.16177 to 0.13015, saving model to asels.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0900 - val_loss: 0.1302
# Epoch 6/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0611
# Epoch 6: val_loss improved from 0.13015 to 0.09421, saving model to asels.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0670 - val_loss: 0.0942
# Epoch 7/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0441
# Epoch 7: val_loss improved from 0.09421 to 0.05145, saving model to asels.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0441 - val_loss: 0.0515
# Epoch 8/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0270
# Epoch 8: val_loss improved from 0.05145 to 0.02945, saving model to asels.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0285 - val_loss: 0.0294
# Epoch 9/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0211
# Epoch 9: val_loss improved from 0.02945 to 0.01860, saving model to asels.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0220 - val_loss: 0.0186
# Epoch 10/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0154
# Epoch 10: val_loss improved from 0.01860 to 0.01345, saving model to asels.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0172 - val_loss: 0.0134
# Epoch 11/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0179
# Epoch 11: val_loss improved from 0.01345 to 0.01059, saving model to asels.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0179 - val_loss: 0.0106
# Epoch 12/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0172
# Epoch 12: val_loss improved from 0.01059 to 0.00892, saving model to asels.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0179 - val_loss: 0.0089
# Epoch 13/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0160
# Epoch 13: val_loss improved from 0.00892 to 0.00772, saving model to asels.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0165 - val_loss: 0.0077
# Epoch 14/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0137
# Epoch 14: val_loss improved from 0.00772 to 0.00702, saving model to asels.h5
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0147 - val_loss: 0.0070
# Epoch 15/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0132
# Epoch 15: val_loss improved from 0.00702 to 0.00664, saving model to asels.h5
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0136 - val_loss: 0.0066
# Epoch 16/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0141
# Epoch 16: val_loss improved from 0.00664 to 0.00610, saving model to asels.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0141 - val_loss: 0.0061
# Epoch 17/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0122
# Epoch 17: val_loss improved from 0.00610 to 0.00585, saving model to asels.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0135 - val_loss: 0.0058
# Epoch 18/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0131
# Epoch 18: val_loss improved from 0.00585 to 0.00552, saving model to asels.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0132 - val_loss: 0.0055
# Epoch 19/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0148
# Epoch 19: val_loss improved from 0.00552 to 0.00546, saving model to asels.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0151 - val_loss: 0.0055
# Epoch 20/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0129
# Epoch 20: val_loss improved from 0.00546 to 0.00518, saving model to asels.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0131 - val_loss: 0.0052
# Epoch 21/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0124
# Epoch 21: val_loss improved from 0.00518 to 0.00474, saving model to asels.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0128 - val_loss: 0.0047
# Epoch 22/500
# 62/64 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 22: val_loss improved from 0.00474 to 0.00453, saving model to asels.h5
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0138 - val_loss: 0.0045
# Epoch 23/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0127
# Epoch 23: val_loss improved from 0.00453 to 0.00431, saving model to asels.h5
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0130 - val_loss: 0.0043
# Epoch 24/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0116
# Epoch 24: val_loss improved from 0.00431 to 0.00410, saving model to asels.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0125 - val_loss: 0.0041
# Epoch 25/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0112
# Epoch 25: val_loss improved from 0.00410 to 0.00407, saving model to asels.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0114 - val_loss: 0.0041
# Epoch 26/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0121
# Epoch 26: val_loss improved from 0.00407 to 0.00387, saving model to asels.h5
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0121 - val_loss: 0.0039
# Epoch 27/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0116
# Epoch 27: val_loss did not improve from 0.00387
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0120 - val_loss: 0.0040
# Epoch 28/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0105
# Epoch 28: val_loss did not improve from 0.00387
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0105 - val_loss: 0.0041
# Epoch 29/500
# 64/64 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 29: val_loss did not improve from 0.00387
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0107 - val_loss: 0.0040
# Epoch 30/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0102
# Epoch 30: val_loss did not improve from 0.00387
# 64/64 [==============================] - 2s 30ms/step - loss: 0.0103 - val_loss: 0.0040
# Epoch 31/500
# 63/64 [============================>.] - ETA: 0s - loss: 0.0098
# Epoch 31: val_loss did not improve from 0.00387
# 64/64 [==============================] - 2s 30ms/step - loss: 0.0107 - val_loss: 0.0040
# Epoch 31: early stopping
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0040
#
# Test kaybı: 0.4%
# 64/64 [==============================] - 1s 6ms/step
# 16/16 [==============================] - 0s 5ms/step
# C:\Users\musab\AppData\Local\Temp\ipykernel_16096\2734381488.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_prediction_df["Tahmin Edilen"] = train_predict
# C:\Users\musab\AppData\Local\Temp\ipykernel_16096\2734381488.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_prediction_df["Tahmin Edilen"] = test_predict

# %%
#MAE hesaplama
train_mae = mean_absolute_error(Y_train, train_predict)
test_mae = mean_absolute_error(Y_test, test_predict)
print(f"Eğitim MAE: {train_mae}")
print(f"Test MAE: {test_mae}")

#MAPE hesaplama
train_mape = mean_absolute_percentage_error(Y_train, train_predict) * 100
test_mape = mean_absolute_percentage_error(Y_test, test_predict) * 100
print(f"Eğitim MAPE: {train_mape}%")
print(f"Test MAPE: {test_mape}%")

#RMSE hesaplama
train_rmse = np.sqrt(mean_squared_error(Y_train, train_predict))
test_rmse = np.sqrt(mean_squared_error(Y_test, test_predict))
print(f"Eğitim RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Eğitim MAE: 0.31165313720703125
# Test MAE: 2.572753667831421
# Eğitim MAPE: 6.607595831155777%
# Test MAPE: 7.8253597021102905%
# Eğitim RMSE: 0.5184351801872253
# Test RMSE: 3.5144524574279785
