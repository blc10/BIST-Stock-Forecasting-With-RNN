# %%
import yfinance as yf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# Veriyi indirme ve inceleme
ticker_symbol = 'ASELS.IS'
start_date = '2022-05-10'
end_date = '2024-04-10'
df = yf.download(ticker_symbol, period="2y", interval="60m")
df['Date'] = pd.to_datetime(df.index)

# Veri hazırlama
df["Date"] = pd.to_datetime(df["Date"])
asels_df = df[["Date", "Close"]]
asels_df.index = asels_df["Date"]
asels_df.drop("Date", axis=1, inplace=True)
result_df = asels_df.copy()
plt.figure(figsize=(12,6))
plt.plot(asels_df['Close'], color='blue')
plt.ylabel('Fiyat')
plt.title('Aselsan Grafiği')
plt.xlabel('Zaman')
plt.show()

# Veri önişleme
asels_df = asels_df.values.astype('float32')
def split_data(dataframe, test_size):
    pos = int(round(len(dataframe) * (1 - test_size)))
    train = dataframe[:pos]
    test = dataframe[pos:]
    return train, test, pos

train, test, pos = split_data(asels_df, 0.20)
scaler_train = MinMaxScaler(feature_range=(0, 1))
train = scaler_train.fit_transform(train)
scaler_test = MinMaxScaler(feature_range=(0, 1))
test = scaler_test.fit_transform(test)

def create_features(data, lookback):
    X, Y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i-lookback:i, 0])
        Y.append(data[i, 0])
    return np.array(X), np.array(Y)

lookback = 40
X_train, Y_train = create_features(train, lookback)
X_test, Y_test = create_features(test, lookback)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
Y_train = Y_train.reshape(-1, 1)
Y_test = Y_test.reshape(-1, 1)

# Model oluşturma
model = Sequential([
    SimpleRNN(units=20, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], lookback)),
    Dropout(0.1),
    SimpleRNN(units=10, activation='relu'),
    Dropout(0.1),
    Dense(1)
])


model.summary()

# Optimizasyon
optimizer = Adam(learning_rate=0.0001)
model.compile(loss='mean_squared_error', optimizer=optimizer)

# Callback'ler
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode="min"),
    ModelCheckpoint(filepath='asels.h5', monitor='val_loss', mode='min',
                    save_best_only=True, save_weights_only=False, verbose=1)
]

# Model eğitimi
history = model.fit(
    x=X_train,
    y=Y_train,
    epochs=1000,
    batch_size=32,
    validation_data=(X_test, Y_test),
    callbacks=callbacks,
    shuffle=False
)

# Eğitim ve doğrulama kaybını görselleştirme
plt.figure(figsize=(20,5))
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.legend(loc='upper right')
plt.xlabel('Epok', fontsize=16)
plt.ylabel('Kayıp', fontsize=16)
plt.ylim([0,max(plt.ylim())])
plt.title('Eğitim ve Doğrulama Kaybı', fontsize=16)
plt.show()

# Model değerlendirme
loss = model.evaluate(X_test, Y_test, batch_size=32)
print("\nTest kaybı: %.1f%%" % (100.0 * loss))
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
train_predict = scaler_train.inverse_transform(train_predict)
test_predict = scaler_test.inverse_transform(test_predict)
Y_train = scaler_train.inverse_transform(Y_train)
Y_test = scaler_test.inverse_transform(Y_test)


# Tahminleri görselleştirme
train_prediction_df = result_df[lookback:pos]
train_prediction_df["Tahmin Edilen"] = train_predict
test_prediction_df = result_df[pos+lookback:]
test_prediction_df["Tahmin Edilen"] = test_predict

plt.figure(figsize=(14,5))
plt.plot(result_df, label='Gerçek Değerler')
plt.plot(train_prediction_df["Tahmin Edilen"], color='blue', label='Eğitim Tahmini')
plt.plot(test_prediction_df["Tahmin Edilen"], color="red", label='Test Tahmini')
plt.xlabel('Zaman')
plt.ylabel('Fiyat')
plt.title('ASELSAN GRAFİĞİ')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\musab\AppData\Local\Temp\ipykernel_11556\2693758008.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asels_df.drop("Date", axis=1, inplace=True)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 20)             1220
#
#  dropout (Dropout)           (None, 1, 20)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 10)                310
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 1,541
# Trainable params: 1,541
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 101/105 [===========================>..] - ETA: 0s - loss: 0.3423
# Epoch 1: val_loss improved from inf to 0.20048, saving model to asels.h5
# 105/105 [==============================] - 4s 16ms/step - loss: 0.3576 - val_loss: 0.2005
# Epoch 2/1000
# 102/105 [============================>.] - ETA: 0s - loss: 0.1020
# Epoch 2: val_loss improved from 0.20048 to 0.06480, saving model to asels.h5
# 105/105 [==============================] - 1s 11ms/step - loss: 0.1078 - val_loss: 0.0648
# Epoch 3/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0511
# Epoch 3: val_loss improved from 0.06480 to 0.02594, saving model to asels.h5
# 105/105 [==============================] - 2s 18ms/step - loss: 0.0525 - val_loss: 0.0259
# Epoch 4/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0354
# Epoch 4: val_loss improved from 0.02594 to 0.01295, saving model to asels.h5
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0354 - val_loss: 0.0129
# Epoch 5/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0345
# Epoch 5: val_loss improved from 0.01295 to 0.00877, saving model to asels.h5
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0349 - val_loss: 0.0088
# Epoch 6/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0325
# Epoch 6: val_loss improved from 0.00877 to 0.00729, saving model to asels.h5
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0340 - val_loss: 0.0073
# Epoch 7/1000
# 102/105 [============================>.] - ETA: 0s - loss: 0.0273
# Epoch 7: val_loss improved from 0.00729 to 0.00702, saving model to asels.h5
# 105/105 [==============================] - 2s 19ms/step - loss: 0.0297 - val_loss: 0.0070
# Epoch 8/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0233
# Epoch 8: val_loss improved from 0.00702 to 0.00660, saving model to asels.h5
# 105/105 [==============================] - 2s 22ms/step - loss: 0.0247 - val_loss: 0.0066
# Epoch 9/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0243
# Epoch 9: val_loss did not improve from 0.00660
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0243 - val_loss: 0.0066
# Epoch 10/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0209
# Epoch 10: val_loss did not improve from 0.00660
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0211 - val_loss: 0.0068
# Epoch 11/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0195
# Epoch 11: val_loss improved from 0.00660 to 0.00653, saving model to asels.h5
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0205 - val_loss: 0.0065
# Epoch 12/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0191
# Epoch 12: val_loss improved from 0.00653 to 0.00630, saving model to asels.h5
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0194 - val_loss: 0.0063
# Epoch 13/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0185
# Epoch 13: val_loss improved from 0.00630 to 0.00594, saving model to asels.h5
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0188 - val_loss: 0.0059
# Epoch 14/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0172
# Epoch 14: val_loss improved from 0.00594 to 0.00578, saving model to asels.h5
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0172 - val_loss: 0.0058
# Epoch 15/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0171
# Epoch 15: val_loss did not improve from 0.00578
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0171 - val_loss: 0.0061
# Epoch 16/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0163
# Epoch 16: val_loss improved from 0.00578 to 0.00551, saving model to asels.h5
# 105/105 [==============================] - 2s 22ms/step - loss: 0.0164 - val_loss: 0.0055
# Epoch 17/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0146
# Epoch 17: val_loss did not improve from 0.00551
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0148 - val_loss: 0.0059
# Epoch 18/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0146
# Epoch 18: val_loss did not improve from 0.00551
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0153 - val_loss: 0.0059
# Epoch 19/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 19: val_loss improved from 0.00551 to 0.00546, saving model to asels.h5
# 105/105 [==============================] - 2s 22ms/step - loss: 0.0152 - val_loss: 0.0055
# Epoch 20/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0149
# Epoch 20: val_loss did not improve from 0.00546
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0155 - val_loss: 0.0056
# Epoch 21/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0135
# Epoch 21: val_loss did not improve from 0.00546
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0136 - val_loss: 0.0057
# Epoch 22/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0121
# Epoch 22: val_loss did not improve from 0.00546
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0124 - val_loss: 0.0055
# Epoch 23/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 23: val_loss improved from 0.00546 to 0.00541, saving model to asels.h5
# 105/105 [==============================] - 2s 22ms/step - loss: 0.0133 - val_loss: 0.0054
# Epoch 24/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 24: val_loss improved from 0.00541 to 0.00533, saving model to asels.h5
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0127 - val_loss: 0.0053
# Epoch 25/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0130
# Epoch 25: val_loss did not improve from 0.00533
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0134 - val_loss: 0.0055
# Epoch 26/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0137
# Epoch 26: val_loss improved from 0.00533 to 0.00516, saving model to asels.h5
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0138 - val_loss: 0.0052
# Epoch 27/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0116
# Epoch 27: val_loss did not improve from 0.00516
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0122 - val_loss: 0.0054
# Epoch 28/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0119
# Epoch 28: val_loss did not improve from 0.00516
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0121 - val_loss: 0.0053
# Epoch 29/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0124
# Epoch 29: val_loss did not improve from 0.00516
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0126 - val_loss: 0.0052
# Epoch 30/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0120
# Epoch 30: val_loss did not improve from 0.00516
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0123 - val_loss: 0.0053
# Epoch 31/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0128
# Epoch 31: val_loss improved from 0.00516 to 0.00507, saving model to asels.h5
# 105/105 [==============================] - 2s 22ms/step - loss: 0.0128 - val_loss: 0.0051
# Epoch 32/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0113
# Epoch 32: val_loss did not improve from 0.00507
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0113 - val_loss: 0.0054
# Epoch 33/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0115
# Epoch 33: val_loss did not improve from 0.00507
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0116 - val_loss: 0.0052
# Epoch 34/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 34: val_loss improved from 0.00507 to 0.00487, saving model to asels.h5
# 105/105 [==============================] - 2s 22ms/step - loss: 0.0126 - val_loss: 0.0049
# Epoch 35/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0118
# Epoch 35: val_loss did not improve from 0.00487
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0118 - val_loss: 0.0050
# Epoch 36/1000
# 104/105 [============================>.] - ETA: 0s - loss: 0.0110
# Epoch 36: val_loss did not improve from 0.00487
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0110 - val_loss: 0.0049
# Epoch 37/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0098
# Epoch 37: val_loss did not improve from 0.00487
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0103 - val_loss: 0.0050
# Epoch 38/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0108
# Epoch 38: val_loss improved from 0.00487 to 0.00464, saving model to asels.h5
# 105/105 [==============================] - 2s 22ms/step - loss: 0.0108 - val_loss: 0.0046
# Epoch 39/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0113
# Epoch 39: val_loss did not improve from 0.00464
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0119 - val_loss: 0.0049
# Epoch 40/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0102
# Epoch 40: val_loss did not improve from 0.00464
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0102 - val_loss: 0.0047
# Epoch 41/1000
# 103/105 [============================>.] - ETA: 0s - loss: 0.0100
# Epoch 41: val_loss did not improve from 0.00464
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0104 - val_loss: 0.0048
# Epoch 42/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0099
# Epoch 42: val_loss did not improve from 0.00464
# 105/105 [==============================] - 2s 21ms/step - loss: 0.0099 - val_loss: 0.0049
# Epoch 43/1000
# 105/105 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 43: val_loss did not improve from 0.00464
# 105/105 [==============================] - 2s 20ms/step - loss: 0.0104 - val_loss: 0.0047
# Epoch 43: early stopping
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0047
#
# Test kaybı: 0.5%
# 105/105 [==============================] - 1s 5ms/step
# 26/26 [==============================] - 0s 5ms/step
# C:\Users\musab\AppData\Local\Temp\ipykernel_11556\2693758008.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_prediction_df["Tahmin Edilen"] = train_predict
# C:\Users\musab\AppData\Local\Temp\ipykernel_11556\2693758008.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_prediction_df["Tahmin Edilen"] = test_predict

# %%
#MAE hesaplama
train_mae = mean_absolute_error(Y_train, train_predict)
test_mae = mean_absolute_error(Y_test, test_predict)
print(f"Eğitim MAE: {train_mae}")
print(f"Test MAE: {test_mae}")

#MAPE hesaplama
train_mape = mean_absolute_percentage_error(Y_train, train_predict) * 100
test_mape = mean_absolute_percentage_error(Y_test, test_predict) * 100
print(f"Eğitim MAPE: {train_mape}%")
print(f"Test MAPE: {test_mape}%")

#RMSE hesaplama
train_rmse = np.sqrt(mean_squared_error(Y_train, train_predict))
test_rmse = np.sqrt(mean_squared_error(Y_test, test_predict))
print(f"Eğitim RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Eğitim MAE: 1.1150301694869995
# Test MAE: 1.2286813259124756
# Eğitim MAPE: 5.574726685881615%
# Test MAPE: 2.2036245092749596%
# Eğitim RMSE: 1.4044471979141235
# Test RMSE: 1.6279168128967285
