# %%
import yfinance as yf
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# Veriyi indirme ve inceleme
ticker_symbol = 'OSTIM.IS'
start_date = '2022-05-10'
end_date = '2024-04-10'
df = yf.download(ticker_symbol, period="10y", interval="1d")
df['Date'] = pd.to_datetime(df.index)

# Veri hazırlama
df["Date"] = pd.to_datetime(df["Date"])
OSTIM_df = df[["Date", "Close"]]
OSTIM_df.index = OSTIM_df["Date"]
OSTIM_df.drop("Date", axis=1, inplace=True)
result_df = OSTIM_df.copy()
plt.figure(figsize=(12,6))
plt.plot(OSTIM_df['Close'], color='blue')
plt.ylabel('Fiyat')
plt.title('OSTIM Grafiği')
plt.xlabel('Zaman')
plt.show()

# Veri önişleme
OSTIM_df = OSTIM_df.values.astype('float32')
def split_data(dataframe, test_size):
    pos = int(round(len(dataframe) * (1 - test_size)))
    train = dataframe[:pos]
    test = dataframe[pos:]
    return train, test, pos

train, test, pos = split_data(OSTIM_df, 0.20)
scaler_train = MinMaxScaler(feature_range=(0, 1))
train = scaler_train.fit_transform(train)
scaler_test = MinMaxScaler(feature_range=(0, 1))
test = scaler_test.fit_transform(test)

def create_features(data, lookback):
    X, Y = [], []
    for i in range(lookback, len(data)):
        X.append(data[i-lookback:i, 0])
        Y.append(data[i, 0])
    return np.array(X), np.array(Y)

lookback = 20
X_train, Y_train = create_features(train, lookback)
X_test, Y_test = create_features(test, lookback)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))
Y_train = Y_train.reshape(-1, 1)
Y_test = Y_test.reshape(-1, 1)

# Model oluşturma
model = Sequential([
    SimpleRNN(units=20, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], lookback)),
    Dropout(0.1),
    SimpleRNN(units=10, activation='relu'),
    Dropout(0.1),
    Dense(1)
])


model.summary()

# Optimizasyon
optimizer = Adam(learning_rate=0.0001)
model.compile(loss='mean_squared_error', optimizer=optimizer)

# Callback'ler
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode="min"),
    ModelCheckpoint(filepath='OSTIM.h5', monitor='val_loss', mode='min',
                    save_best_only=True, save_weights_only=False, verbose=1)
]

# Model eğitimi
history = model.fit(
    x=X_train,
    y=Y_train,
    epochs=1000,
    batch_size=32,
    validation_data=(X_test, Y_test),
    callbacks=callbacks,
    shuffle=False
)

# Eğitim ve doğrulama kaybını görselleştirme
plt.figure(figsize=(20,5))
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Eğitim Kaybı')
plt.plot(history.history['val_loss'], label='Doğrulama Kaybı')
plt.legend(loc='upper right')
plt.xlabel('Epok', fontsize=16)
plt.ylabel('Kayıp', fontsize=16)
plt.ylim([0,max(plt.ylim())])
plt.title('Eğitim ve Doğrulama Kaybı', fontsize=16)
plt.show()

# Model değerlendirme
loss = model.evaluate(X_test, Y_test, batch_size=32)
print("\nTest kaybı: %.1f%%" % (100.0 * loss))
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
train_predict = scaler_train.inverse_transform(train_predict)
test_predict = scaler_test.inverse_transform(test_predict)
Y_train = scaler_train.inverse_transform(Y_train)
Y_test = scaler_test.inverse_transform(Y_test)


# Tahminleri görselleştirme
train_prediction_df = result_df[lookback:pos]
train_prediction_df["Tahmin Edilen"] = train_predict
test_prediction_df = result_df[pos+lookback:]
test_prediction_df["Tahmin Edilen"] = test_predict

plt.figure(figsize=(14,5))
plt.plot(result_df, label='Gerçek Değerler')
plt.plot(train_prediction_df["Tahmin Edilen"], color='blue', label='Eğitim Tahmini')
plt.plot(test_prediction_df["Tahmin Edilen"], color="red", label='Test Tahmini')
plt.xlabel('Zaman')
plt.ylabel('Fiyat')
plt.title('OSTIM GRAFİĞİ')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\musab\AppData\Local\Temp\ipykernel_15096\1408629188.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OSTIM_df.drop("Date", axis=1, inplace=True)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 20)             820
#
#  dropout (Dropout)           (None, 1, 20)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 10)                310
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 1,141
# Trainable params: 1,141
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.2409
# Epoch 1: val_loss improved from inf to 0.21514, saving model to OSTIM.h5
# 64/64 [==============================] - 4s 25ms/step - loss: 0.2409 - val_loss: 0.2151
# Epoch 2/1000
# 62/64 [============================>.] - ETA: 0s - loss: 0.1673
# Epoch 2: val_loss improved from 0.21514 to 0.14367, saving model to OSTIM.h5
# 64/64 [==============================] - 1s 14ms/step - loss: 0.1698 - val_loss: 0.1437
# Epoch 3/1000
# 60/64 [===========================>..] - ETA: 0s - loss: 0.1121
# Epoch 3: val_loss improved from 0.14367 to 0.09445, saving model to OSTIM.h5
# 64/64 [==============================] - 1s 14ms/step - loss: 0.1169 - val_loss: 0.0944
# Epoch 4/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0857
# Epoch 4: val_loss improved from 0.09445 to 0.05815, saving model to OSTIM.h5
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0857 - val_loss: 0.0581
# Epoch 5/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0621
# Epoch 5: val_loss improved from 0.05815 to 0.03490, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0631 - val_loss: 0.0349
# Epoch 6/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0581
# Epoch 6: val_loss improved from 0.03490 to 0.02336, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0581 - val_loss: 0.0234
# Epoch 7/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0430
# Epoch 7: val_loss improved from 0.02336 to 0.01740, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0438 - val_loss: 0.0174
# Epoch 8/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0449
# Epoch 8: val_loss improved from 0.01740 to 0.01334, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0449 - val_loss: 0.0133
# Epoch 9/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0385
# Epoch 9: val_loss improved from 0.01334 to 0.01135, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0389 - val_loss: 0.0113
# Epoch 10/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0377
# Epoch 10: val_loss improved from 0.01135 to 0.01003, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0377 - val_loss: 0.0100
# Epoch 11/1000
# 62/64 [============================>.] - ETA: 0s - loss: 0.0329
# Epoch 11: val_loss improved from 0.01003 to 0.00904, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0335 - val_loss: 0.0090
# Epoch 12/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0315
# Epoch 12: val_loss improved from 0.00904 to 0.00834, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0319 - val_loss: 0.0083
# Epoch 13/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0310
# Epoch 13: val_loss improved from 0.00834 to 0.00763, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0310 - val_loss: 0.0076
# Epoch 14/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0276
# Epoch 14: val_loss improved from 0.00763 to 0.00736, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0276 - val_loss: 0.0074
# Epoch 15/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0251
# Epoch 15: val_loss improved from 0.00736 to 0.00681, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0252 - val_loss: 0.0068
# Epoch 16/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0284
# Epoch 16: val_loss improved from 0.00681 to 0.00651, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0284 - val_loss: 0.0065
# Epoch 17/1000
# 62/64 [============================>.] - ETA: 0s - loss: 0.0247
# Epoch 17: val_loss improved from 0.00651 to 0.00629, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0248 - val_loss: 0.0063
# Epoch 18/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0279
# Epoch 18: val_loss improved from 0.00629 to 0.00592, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0279 - val_loss: 0.0059
# Epoch 19/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0260
# Epoch 19: val_loss improved from 0.00592 to 0.00588, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0260 - val_loss: 0.0059
# Epoch 20/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0249
# Epoch 20: val_loss did not improve from 0.00588
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0251 - val_loss: 0.0062
# Epoch 21/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0246
# Epoch 21: val_loss did not improve from 0.00588
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0247 - val_loss: 0.0060
# Epoch 22/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0214
# Epoch 22: val_loss improved from 0.00588 to 0.00582, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0214 - val_loss: 0.0058
# Epoch 23/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0227
# Epoch 23: val_loss improved from 0.00582 to 0.00578, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0227 - val_loss: 0.0058
# Epoch 24/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0203
# Epoch 24: val_loss did not improve from 0.00578
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0205 - val_loss: 0.0058
# Epoch 25/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0230
# Epoch 25: val_loss improved from 0.00578 to 0.00575, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0233 - val_loss: 0.0058
# Epoch 26/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0187
# Epoch 26: val_loss did not improve from 0.00575
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0187 - val_loss: 0.0058
# Epoch 27/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0182
# Epoch 27: val_loss did not improve from 0.00575
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0183 - val_loss: 0.0059
# Epoch 28/1000
# 62/64 [============================>.] - ETA: 0s - loss: 0.0184
# Epoch 28: val_loss improved from 0.00575 to 0.00521, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0186 - val_loss: 0.0052
# Epoch 29/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0191
# Epoch 29: val_loss improved from 0.00521 to 0.00468, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0192 - val_loss: 0.0047
# Epoch 30/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0195
# Epoch 30: val_loss did not improve from 0.00468
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0196 - val_loss: 0.0054
# Epoch 31/1000
# 62/64 [============================>.] - ETA: 0s - loss: 0.0181
# Epoch 31: val_loss did not improve from 0.00468
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0184 - val_loss: 0.0052
# Epoch 32/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 32: val_loss did not improve from 0.00468
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0163 - val_loss: 0.0055
# Epoch 33/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0174
# Epoch 33: val_loss did not improve from 0.00468
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0174 - val_loss: 0.0053
# Epoch 34/1000
# 64/64 [==============================] - ETA: 0s - loss: 0.0177
# Epoch 34: val_loss improved from 0.00468 to 0.00468, saving model to OSTIM.h5
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0177 - val_loss: 0.0047
# Epoch 35/1000
# 62/64 [============================>.] - ETA: 0s - loss: 0.0166
# Epoch 35: val_loss did not improve from 0.00468
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0168 - val_loss: 0.0050
# Epoch 36/1000
# 62/64 [============================>.] - ETA: 0s - loss: 0.0151
# Epoch 36: val_loss did not improve from 0.00468
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0153 - val_loss: 0.0049
# Epoch 37/1000
# 62/64 [============================>.] - ETA: 0s - loss: 0.0153
# Epoch 37: val_loss did not improve from 0.00468
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0156 - val_loss: 0.0049
# Epoch 38/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0171
# Epoch 38: val_loss did not improve from 0.00468
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0173 - val_loss: 0.0050
# Epoch 39/1000
# 63/64 [============================>.] - ETA: 0s - loss: 0.0151
# Epoch 39: val_loss did not improve from 0.00468
# 64/64 [==============================] - 2s 30ms/step - loss: 0.0151 - val_loss: 0.0051
# Epoch 39: early stopping
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0051
#
# Test kaybı: 0.5%
# 64/64 [==============================] - 1s 7ms/step
# 16/16 [==============================] - 0s 8ms/step
# C:\Users\musab\AppData\Local\Temp\ipykernel_15096\1408629188.py:123: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_prediction_df["Tahmin Edilen"] = train_predict
# C:\Users\musab\AppData\Local\Temp\ipykernel_15096\1408629188.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_prediction_df["Tahmin Edilen"] = test_predict

# %%
#MAE hesaplama
train_mae = mean_absolute_error(Y_train, train_predict)
test_mae = mean_absolute_error(Y_test, test_predict)
print(f"Eğitim MAE: {train_mae}")
print(f"Test MAE: {test_mae}")

#MAPE hesaplama
train_mape = mean_absolute_percentage_error(Y_train, train_predict) * 100
test_mape = mean_absolute_percentage_error(Y_test, test_predict) * 100
print(f"Eğitim MAPE: {train_mape}%")
print(f"Test MAPE: {test_mape}%")

#RMSE hesaplama
train_rmse = np.sqrt(mean_squared_error(Y_train, train_predict))
test_rmse = np.sqrt(mean_squared_error(Y_test, test_predict))
print(f"Eğitim RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
# Out:
# Eğitim MAE: 0.06839297711849213
# Test MAE: 0.5858468413352966
# Eğitim MAPE: 6.026887148618698%
# Test MAPE: 9.929073601961136%
# Eğitim RMSE: 0.10283990204334259
# Test RMSE: 0.8920040726661682
